# %% [markdown]
# ## Project Goals
# 1. Load a dictionary of english words into a Python list
# 2. Create a Python dict of anagrams, indexed by anagrammed word
# 3. Challenge: Group dictionary words by their length and then find the total number of anagrams in each group

# %% [markdown]
# part one result >>>
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic',
#  'aaronical',
#  'aaronite',
#  'aaronitic',
#  ...,
#  ]

# %% [markdown]
# Expected from part 2 >>>
#
#     {'acdiinorty':['dictionary', 'indicatory']}

# %% [markdown]
# Expected from part 3 >>>
#
#     {
#     2:145632,
#     3:102634,
#     ...,
#     }

# %%
with open('words.txt') as file:
    data = file.readlines()

# %%
data[:10]
# Out:
# ['A\n',
#  'a\n',
#  'aa\n',
#  'aal\n',
#  'aalii\n',
#  'aam\n',
#  'Aani\n',
#  'aardvark\n',
#  'aardwolf\n',
#  'Aaron\n']

# %%
a = data[0]
a
# Out:
# 'A\n'

# %%
a.strip()
# Out:
# 'A'

# %%
data_n = [word[:-1] for word in data]
data_n[:5]
# Out:
# ['A', 'a', 'aa', 'aal', 'aalii']

# %%
data_n_n = [word.lower() for word in data_n]
data_n_n[:5]
# Out:
# ['a', 'a', 'aa', 'aal', 'aalii']

# %%
data_n_n_n = set(data_n_n)
data_n_n_n
# Out:
# {'outissue',
#  'unselfness',
#  'superinfinitely',
#  'inagglutinable',
#  'alopiidae',
#  'agedly',
#  'ophionid',
#  'meteorous',
#  'overhang',
#  'fifthly',
#  'marla',
#  'spicosity',
#  'vaccinial',
#  'ronga',
#  'gasteromycete',
#  'diverticulitis',
#  'metosteal',
#  'springtail',
#  'hemathidrosis',
#  'craber',
#  'tarsius',
#  'theatrically',
#  'unperspirable',
#  'tetraonine',
#  'unsparingness',
#  'adipometer',
#  'aubepine',
#  'thermopair',
#  'corneagen',
#  'zoophytish',
#  'rakeage',
#  'accursedness',
#  'mountainous',
#  'chivey',
#  'publish',
#  'nulliverse',
#  'subconsul',
#  'carcinomatoid',
#  'azeotropy',
#  'distal',
#  'receptitious',
#  'frenchify',
#  'frette',
#  'millering',
#  'disilane',
#  'befringe',
#  'cynomoriaceae',
#  'kamichi',
#  'nonuniversal',
#  'shrewdom',
#  'smilaceae',
#  'chronogram',
#  'glochidia',
#  'archphilosopher',
#  'reducible',
#  'convectively',
#  'hyposyllogistic',
#  'reformistic',
#  'holour',
#  'dimercuric',
# ...

# %%
data_n_n_n_n = sorted(data_n_n_n)
data_n_n_n_n[:5]
# Out:
# ['a', 'aa', 'aal', 'aalii', 'aam']

# %%
"PoooyA".lower()
# Out:
# 'poooya'

# %%
clean_data = sorted(set([word.strip().lower() for word in data]))
clean_data
# Out:
# ['a',
#  'aa',
#  'aal',
#  'aalii',
#  'aam',
#  'aani',
#  'aardvark',
#  'aardwolf',
#  'aaron',
#  'aaronic',
#  'aaronical',
#  'aaronite',
#  'aaronitic',
#  'aaru',
#  'ab',
#  'aba',
#  'ababdeh',
#  'ababua',
#  'abac',
#  'abaca',
#  'abacate',
#  'abacay',
#  'abacinate',
#  'abacination',
#  'abaciscus',
#  'abacist',
#  'aback',
#  'abactinal',
#  'abactinally',
#  'abaction',
#  'abactor',
#  'abaculus',
#  'abacus',
#  'abadite',
#  'abaff',
#  'abaft',
#  'abaisance',
#  'abaiser',
#  'abaissed',
#  'abalienate',
#  'abalienation',
#  'abalone',
#  'abama',
#  'abampere',
#  'abandon',
#  'abandonable',
#  'abandoned',
#  'abandonedly',
#  'abandonee',
#  'abandoner',
#  'abandonment',
#  'abanic',
#  'abantes',
#  'abaptiston',
#  'abarambo',
#  'abaris',
#  'abarthrosis',
#  'abarticular',
#  'abarticulation',
#  'abas',
#  'abase',
#  'abased',
#  'abasedly',
#  'abasedness',
#  'abasement',
#  'abaser',
#  'abasgi',
#  'abash',
#  'abashed',
#  'abashedly',
# ...

# %%
def signiture(word):
    return ''.join(sorted(word))

# %%
word_dict = dict()

for word in clean_data:
    sig_word = signiture(word)
    if sig_word not in word_dict:
        word_dict[sig_word] = [word]
    else:
        word_dict[sig_word].append(word)

# %%
word_dict
# Out:
# {'a': ['a'],
#  'aa': ['aa'],
#  'aal': ['aal', 'ala'],
#  'aaiil': ['aalii'],
#  'aam': ['aam', 'ama'],
#  'aain': ['aani'],
#  'aaadkrrv': ['aardvark'],
#  'aadflorw': ['aardwolf'],
#  'aanor': ['aaron'],
#  'aacinor': ['aaronic', 'nicarao', 'ocarina'],
#  'aaacilnor': ['aaronical'],
#  'aaeinort': ['aaronite', 'aeration'],
#  'aaciinort': ['aaronitic'],
#  'aaru': ['aaru', 'aura'],
#  'ab': ['ab', 'ba'],
#  'aab': ['aba', 'baa'],
#  'aabbdeh': ['ababdeh'],
#  'aaabbu': ['ababua'],
#  'aabc': ['abac', 'caba'],
#  'aaabc': ['abaca'],
#  'aaabcet': ['abacate'],
#  'aaabcy': ['abacay'],
#  'aaabceint': ['abacinate'],
#  'aaabciinnot': ['abacination'],
#  'aabccissu': ['abaciscus'],
#  'aabcist': ['abacist'],
#  'aabck': ['aback'],
#  'aaabcilnt': ['abactinal'],
#  'aaabcillnty': ['abactinally'],
#  'aabcinot': ['abaction'],
#  'aabcort': ['abactor', 'acrobat'],
#  'aabclsuu': ['abaculus'],
#  'aabcsu': ['abacus'],
#  'aabdeit': ['abadite'],
#  'aabff': ['abaff'],
# ...
