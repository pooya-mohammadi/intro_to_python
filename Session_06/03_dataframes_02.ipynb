# %%
import pandas as pd

# %% [markdown]
# ### Challenge:
# Open file 01_height... and convert male to 1 and female to 0

# %%
files = open('01_heights_weights_genders.csv').readlines()
del files[0]
files[:5]
# Out:
# ['"Male",73.847017017515,241.893563180437\n',
#  '"Male",68.7819040458903,162.310472521300\n',
#  '"Male",74.1101053917849,212.7408555565\n',
#  '"Male",71.7309784033377,220.042470303077\n',
#  '"Male",69.8817958611153,206.349800623871\n']

# %%
tips = pd.read_csv('tips.csv')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
type(tips)
# Out:
# pandas.core.frame.DataFrame

# %%
tips.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
tips.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
tips.tail(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 234       15.53  3.00    Male    Yes   Sat  Dinner     2
# 235       10.07  1.25    Male     No   Sat  Dinner     2
# 236       12.60  1.00    Male    Yes   Sat  Dinner     2
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2
# 238       35.83  4.67  Female     No   Sat  Dinner     3
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips['total_bill']
# Out:
# 0      16.99
# 1      10.34
# 2      21.01
# 3      23.68
# 4      24.59
#        ...
# 239    29.03
# 240    27.18
# 241    22.67
# 242    17.82
# 243    18.78
# Name: total_bill, Length: 244, dtype: float64

# %%
tips[['total_bill']]
# Out:
#      total_bill
# 0         16.99
# 1         10.34
# 2         21.01
# 3         23.68
# 4         24.59
# ..          ...
# 239       29.03
# 240       27.18
# 241       22.67
# 242       17.82
# 243       18.78
#
# [244 rows x 1 columns]

# %%
tips[['total_bill','tip']]
# Out:
#      total_bill   tip
# 0         16.99  1.01
# 1         10.34  1.66
# 2         21.01  3.50
# 3         23.68  3.31
# 4         24.59  3.61
# ..          ...   ...
# 239       29.03  5.92
# 240       27.18  2.00
# 241       22.67  2.00
# 242       17.82  1.75
# 243       18.78  3.00
#
# [244 rows x 2 columns]

# %% [markdown]
# ### Iterate on a dataframes

# %%
total_bill_tip = tips[['total_bill','tip']]
total_bill_tip.head()
# Out:
#    total_bill   tip
# 0       16.99  1.01
# 1       10.34  1.66
# 2       21.01  3.50
# 3       23.68  3.31
# 4       24.59  3.61

# %%
for total_bill , tip in total_bill_tip.values:
    print(total_bill + tip)
# Out:
# 18.0
# 12.0
# 24.51
# 26.99
# 28.2
# 30.0
# 10.77
# 30.0
# 17.0
# 18.009999999999998
# 11.98
# 40.26
# 16.99
# 21.43
# 17.85
# 25.5
# 12.0
# 20.0
# 20.47
# 24.0
# 22.0
# 23.04
# 18.0
# 47.0
# 23.0
# 20.15
# 15.37
# 14.69
# 26.0
# 22.65
# 11.0
# 20.85
# 18.060000000000002
# 23.14
# 21.05
# 27.66
# 18.31
# 20.0
# 21.0
# 36.269999999999996
# 18.28
# 20.0
# 17.0
# 11.0
# 36.0
# 21.29
# 27.23
# 38.4
# 30.6
# 21.04
# 15.04
# 12.889999999999999
# 40.010000000000005
# 11.5
# 29.9
# 23.0
# 41.01
# 27.91
# 13.0
# 55.0
# 23.5
# 15.81
# 13.0
# 22.049999999999997
# 20.23
# 23.229999999999997
# 18.919999999999998
# 4.07
# 22.240000000000002
# 17.1
# 13.99
# 20.07
# 30.0
# 30.28
# 16.93
# 11.76
# 21.0
# 31.2
# 25.76
# 20.0
# 22.44
# 20.06
# 11.9
# 37.68
# 18.01
# 40.0
# 15.03
# 22.28
# 30.560000000000002
# 24.16
# 31.97
# 25.99
# 6.75
# 20.62
# 26.0
# 44.900000000000006
# 31.28
# 13.53
# 24.01
# 13.96
# 13.85
# 18.380000000000003
# 46.8
# 25.900000000000002
# 25.0
# 17.0
# 24.549999999999997
# ...

# %% [markdown]
# ### inplace & drop

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips= tips.drop(['total_bill','tip'] , axis=1)
new_tips.head()
# Out:
#       sex smoker  day    time  size
# 0  Female     No  Sun  Dinner     2
# 1    Male     No  Sun  Dinner     3
# 2    Male     No  Sun  Dinner     3
# 3    Male     No  Sun  Dinner     2
# 4  Female     No  Sun  Dinner     4

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.drop(['total_bill','tip'], axis=1)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.drop(['total_bill', 'tip'],axis=1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-80468d76b148> in <module>
# ----> 1 tips.drop(['total_bill', 'tip'],axis=1, inplace = True)
#
# G:\SetupDir\Anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4100             level=level,
#    4101             inplace=inplace,
# -> 4102             errors=errors,
#    4103         )
#    4104
#
# G:\SetupDir\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3912         for axis, labels in axes.items():
#    3913             if labels is not None:
# -> 3914                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3915
#    3916         if inplace:
#
# ...

# %%
tips.head()
# Out:
#       sex smoker  day    time  size
# 0  Female     No  Sun  Dinner     2
# 1    Male     No  Sun  Dinner     3
# 2    Male     No  Sun  Dinner     3
# 3    Male     No  Sun  Dinner     2
# 4  Female     No  Sun  Dinner     4

# %%
tips.drop(['total_bill','tip'],axis=1, inplace = True)
tips.head()

# %%
tips = pd.read_csv('tips.csv')
tips.head()

# %% [markdown]
# ### do the same task using pandas

# %%
df = pd.read_csv('01_heights_weights_genders.csv')
df.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
information = pd.read_csv('01_heights_weights_genders.csv')
information['Gender'] = [1 if gender == 'Male' else 0 for gender in information.Gender]
information.head()

# %%
information = pd.read_csv('01_heights_weights_genders.csv')
lst = []
for gender in information.Gender:
    lst.append(1 if gender == 'Male' else 0)
lst[:10]

# %%
information['Gender']= lst

# %%
information.head()

# %% [markdown]
# *:)*
