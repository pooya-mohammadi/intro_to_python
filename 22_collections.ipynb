# %% [markdown]
# ## Collections
#     1 ChainMap
#     2 namedtuple
#     3 Counter
#     4 defaultdict
#     5. Exercise

# %% [markdown]
# ### ChainMap
#     A ChainMap groups multiple dicts (or other mappings) together to create a single, updateable view.

# %%
from collections import ChainMap

# %%
dict_1 = {'a': 1, 'b': 2} 
dict_2 = {'c': 3, 'd': 4} 
dict_3 = {'e': 5, 'f': 6}

# %%
# Defining the chainmap  
result = ChainMap(dict_1, dict_2, dict_3)
result
# Out:
# ChainMap({'a': 1, 'b': 2}, {'c': 3, 'd': 4}, {'e': 5, 'f': 6})

# %%
for k, v in result.items():
    print(f"key: {k}, value: {v}")
# Out:
# key: e, value: 5
# key: f, value: 6
# key: c, value: 3
# key: d, value: 4
# key: a, value: 1
# key: b, value: 2

# %%
# main view
result.maps
# Out:
# [{'a': 1, 'b': 2}, {'c': 3, 'd': 4}, {'e': 5, 'f': 6}]

# %%
dict_4 = {'s': 6, 'b': 0}

# %%
# Adding a new dict is possible
res = result.new_child(dict_4)
res
# Out:
# ChainMap({'s': 6, 'b': 0}, {'a': 1, 'b': 2}, {'c': 3, 'd': 4}, {'e': 5, 'f': 6})

# %%
# Adding a new dict is possible
res.maps.append({'m': 13})
res
# Out:
# ChainMap({'s': 6, 'b': 0}, {'a': 1, 'b': 2}, {'c': 3, 'd': 4}, {'e': 5, 'f': 6}, {'m': 13})

# %%
# Access each dict 
for mapping in res.maps:
    print(mapping)
# Out:
# {'s': 6, 'b': 0}
# {'a': 1, 'b': 2}
# {'c': 3, 'd': 4}
# {'e': 5, 'f': 6}
# {'m': 13}

# %%
# Access values 
res['b']
# Out:
# 0

# %%
list(reversed(res.maps))
# Out:
# [{'m': 13},
#  {'e': 5, 'f': 6},
#  {'c': 3, 'd': 4},
#  {'a': 1, 'b': 2},
#  {'s': 6, 'b': 0}]

# %%
# Reverse a list of dicts
res.maps = list(reversed(res.maps))
res
# Out:
# ChainMap({'m': 13}, {'e': 5, 'f': 6}, {'c': 3, 'd': 4}, {'a': 1, 'b': 2}, {'s': 6, 'b': 0})

# %%
# Access from the end!
res['b']
# Out:
# 2

# %%
dict_1 = {'a': 1, 'b': 2} 
dict_2 = {'c': 3, 'd': 4} 
dict_3 = {'e': 5, 'f': 6} 
dict_4 = {'s': 6, 'b': 0}

# %%
res_ = {}
res_.update(dict_1)
res_.update(dict_2)
res_.update(dict_3)
res_.update(dict_4)

# %%
res_ # throwing out the ability to manage and prioritize the access to repeated keys using multiple scopes or contexts.
# Out:
# {'a': 1, 'b': 0, 'c': 3, 'd': 4, 'e': 5, 'f': 6, 's': 6}

# %%
# Add a new value to chainmap
res["pooya"] = "mohammadi"
res
# Out:
# ChainMap({'m': 13, 'pooya': 'mohammadi'}, {'e': 5, 'f': 6}, {'c': 3, 'd': 4}, {'a': 1, 'b': 2}, {'s': 6, 'b': 0})

# %%
res['m'] = 10
res
# Out:
# ChainMap({'m': 10, 'pooya': 'mohammadi', 'e': 10}, {'e': 5, 'f': 6}, {'c': 3, 'd': 4}, {'a': 1, 'b': 2}, {'s': 6, 'b': 0})

# %%
res['f'] = 16
res
# Out:
# ChainMap({'m': 10, 'pooya': 'mohammadi', 'e': 10, 'f': 16}, {'e': 5, 'f': 6}, {'c': 3, 'd': 4}, {'a': 1, 'b': 2}, {'s': 6, 'b': 0})

# %%
res.pop("pooya")
# Out:
# 'mohammadi'

# %% [markdown]
# ### namedtuple()
#     factory function for creating tuple subclasses with named fields
#     Sometimes working with named fields are easier than working with indices!

# %%
from collections import namedtuple

# %%
student = ('Zahra', 21, '1380')

# %%
student[0]
# Out:
# 'Zahra'

# %%
# Age
student[1]
# Out:
# 21

# %%
Student = namedtuple('Student', ['name', 'age', 'DOB'])

# %%
s_1 = Student('Zahra', 21, '1380')
s_1
# Out:
# Student(name='Zahra', age=21, DOB='1380')

# %%
# Access by index
s_1[1]
# Out:
# 21

# %%
# Access by field name
s_1.age, s_1.name, s_1.DOB
# Out:
# (21, 'Zahra', '1380')

# %%
s_1.name = "pooya"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [41], line 1
# ----> 1 s_1.name = "pooya"
#
# AttributeError: can't set attribute

# %%
# creates a new tuple
s_2 = s_1._replace(name='Anahid')
s_2
# Out:
# Student(name='Anahid', age=21, DOB='1380')

# %%
s_1
# Out:
# Student(name='Zahra', age=21, DOB='1380')

# %%
# create from dict
dic = {'name': "Fereshteh", 'age': 19, 'DOB': '1381'}

# %%
s_2 = Student(**dic)
s_2
# Out:
# Student(name='Fereshteh', age=19, DOB='1381')

# %%
# create from a list
lst = ['pooya', 28, '1373']

# %%
# recommended
Student._make(lst)
# Out:
# Student(name='pooya', age=28, DOB='1373')

# %%
# recommended!
# unpacking
Student(*lst)
# Out:
# Student(name='pooya', age=28, DOB='1373')

# %% [markdown]
# ### Counter
#     dict like object for counting sequences of hashable objects

# %%
sequence = "pooya-mohammadi"
counter = dict()
for letter in sequence:
    counter[letter] = counter.get(letter, 0) + 1

counter
# Out:
# {'p': 1, 'o': 3, 'y': 1, 'a': 3, '-': 1, 'm': 3, 'h': 1, 'd': 1, 'i': 1}

# %%
from collections import Counter

# %%
example = Counter("pooya-mohammadi")
example
# Out:
# Counter({'p': 1,
#          'o': 3,
#          'y': 1,
#          'a': 3,
#          '-': 1,
#          'm': 3,
#          'h': 1,
#          'd': 1,
#          'i': 1})

# %%
for item in example.elements():
    print(item)
# Out:
# p
# o
# o
# o
# y
# a
# a
# a
# -
# m
# m
# m
# h
# d
# i

# %%
# get most common
example.most_common(1)
# Out:
# [('o', 3)]

# %%
example.most_common(4)
# Out:
# [('o', 3), ('a', 3), ('m', 3), ('p', 1)]

# %%
# Update with other sequences!
example.update("intro_to_python")
example
# Out:
# Counter({'p': 2,
#          'o': 6,
#          'y': 2,
#          'a': 3,
#          '-': 1,
#          'm': 3,
#          'h': 2,
#          'd': 1,
#          'i': 2,
#          'n': 2,
#          't': 3,
#          'r': 1,
#          '_': 2})

# %%
example.most_common(1)
# Out:
# [('o', 6)]

# %%
example_2 = Counter([1, 3, 4, 5, 5, 6, 9, 9, 9])
example_2
# Out:
# Counter({1: 1, 3: 1, 4: 1, 5: 2, 6: 1, 9: 3})

# %%
example_2 = Counter([1, "3", 4, 5, "5", 6, 9, 9, 9])
example_2
# Out:
# Counter({1: 1, '3': 1, 4: 1, 5: 1, '5': 1, 6: 1, 9: 3})

# %%
# it does not work for sequences containing unhashable objects!
example_3 = Counter([1, "3", 4, 5, "5", 6, 9, 9, [9, "lists are not hashable"]])
example_3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [61], line 1
# ----> 1 example_3 = Counter([1, "3", 4, 5, "5", 6, 9, 9, [9, "lists are not hashable"]])
#       2 example_3
#
# File ~\miniconda3\envs\torch_gpu\lib\collections\__init__.py:577, in Counter.__init__(self, iterable, **kwds)
#     566 '''Create a new, empty Counter object.  And if given, count elements
#     567 from an input iterable.  Or, initialize the count from another mapping
#     568 of elements to their counts.
#    (...)
#     574
#     575 '''
#     576 super().__init__()
# --> 577 self.update(iterable, **kwds)
#
# File ~\miniconda3\envs\torch_gpu\lib\collections\__init__.py:670, in Counter.update(self, iterable, **kwds)
#     668             super().update(iterable)
#     669     else:
# --> 670         _count_elements(self, iterable)
#     671 if kwds:
#     672     self.update(kwds)
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# ### defaultdict()
#     dict like object that calls a factory function to supply missing values and prevent KeyError

# %%
# dct counts the number of occurrences of some keys!
dct = dict()
dct["a"] = 1
dct["b"] = 2
  
print(dct["a"])
print(dct["b"])
print(dct["c"])
# Out:
# 1
# 2
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [62], line 8
#       6 print(dct["a"])
#       7 print(dct["b"])
# ----> 8 print(dct["c"])
#
# KeyError: 'c'

# %%
from collections import defaultdict

# %%
# default value of int
default_value = int()
default_value
# Out:
# 0

# %%
dct = defaultdict(int)
dct["a"] = 1
dct["b"] = 2
  
print(dct["a"])
print(dct["b"])
print(dct["c"])
# Out:
# 1
# 2
# 0

# %%
dct
# Out:
# defaultdict(int, {'a': 1, 'b': 2, 'c': 0})

# %%
# default value of list
default_value = list()
default_value
# Out:
# []

# %%
dct = defaultdict(list) # creates an empty list
dct["c"], dct
# Out:
# ([], defaultdict(list, {'c': []}))

# %%
dct = defaultdict(set) # creates an empty set
dct["c"], dct
# Out:
# (set(), defaultdict(set, {'c': set()}))

# %%
dct['c'].add("p")
dct['c'].add("d")
dct['d'].add("pooya")
dct['d'].add("mohammadi")
dct
# Out:
# defaultdict(set, {'c': {'d', 'p'}, 'd': {'mohammadi', 'pooya'}})

# %%
dct = defaultdict(list)
  
for num in range(5):
    dct[num].append(num)
dct
# Out:
# defaultdict(list, {0: [0], 1: [1], 2: [2], 3: [3], 4: [4]})

# %%
# sequence = "pooya-mohammadi"
# counter = dict()
# for letter in sequence:
#     counter[letter] = counter.get(letter, 0) + 1

# counter

dct = defaultdict(int)
   
for letter in sequence:
    dct[letter] += 1
dct
# Out:
# defaultdict(int,
#             {'p': 1,
#              'o': 3,
#              'y': 1,
#              'a': 3,
#              '-': 1,
#              'm': 3,
#              'h': 1,
#              'd': 1,
#              'i': 1})

# %%
# default dict of dicts!
dct = defaultdict(dict)
dct["names"]
# Out:
# {}

# %%
dct['names']["pooya"] = "mohammadi!"
dct['friends']["Zahra"] = "Zamani!"
dct
# Out:
# defaultdict(dict,
#             {'names': {'pooya': 'mohammadi!', 'Zahra': 'Zamani!'},
#              'friends': {'Zahra': 'Zamani!'}})

# %% [markdown]
# ### Exercise
#     In a set of english words list and count the number of words with the same anagram.
#     Anagram Defenition: An anagram is a word or phrase formed by rearranging the letters of a different word or phrase, typically using all the original letters exactly once. For example, the word anagram itself can be rearranged into nag a ram, also the word binary into brainy and the word adobe into abode.
#     Anagram example: Brush, shrub

# %% [markdown]
# ### Note: Pause the video and try to do it yourself!!!

# %%
# !pip install english-words
# !pip install git+https://github.com/mwiens91/english-words-py
# https://pypi.org/project/english-words/
# Out:
# WARNING: There was an error checking the latest version of pip.
# Requirement already satisfied: english-words in c:\users\pooya\miniconda3\envs\torch_gpu\lib\site-packages (1.1.0)

# %%
from english_words import english_words_set
print(f"number of English words: {len(english_words_set)}")
# Out:
# number of English words: 25487

# %%
english_words = {word.lower() for word in english_words_set}
english_words
# Out:
# {'auk',
#  'known',
#  'brae',
#  'imperate',
#  'cardboard',
#  'muscovite',
#  'steradian',
#  'skeletal',
#  'multiplet',
#  'bird',
#  'pier',
#  'chitin',
#  'pierre',
#  'complicity',
#  'sunburnt',
#  'screwball',
#  'range',
#  'tau',
#  'eyeglass',
#  'typesetting',
#  'nichrome',
#  'codeword',
#  'relevant',
#  'blind',
#  'mcgrath',
#  'rain',
#  'diesel',
#  'lock',
#  'hypothalamic',
#  'streamside',
#  'inexperience',
#  'backfill',
#  'foe',
#  'irrefutable',
#  'podium',
#  'soggy',
#  'canvasback',
#  'brookside',
#  'elan',
#  'fir',
#  'avignon',
#  'floodlit',
#  'lectern',
#  'helmsmen',
#  'inequitable',
#  'locate',
#  'chart',
#  'dowling',
#  'shadow',
#  'somersault',
#  'hummel',
#  'jackboot',
#  'sputter',
#  'eponymous',
#  'quadruple',
#  'shabby',
#  'transpire',
#  'bouillon',
#  'bluebill',
#  'midas',
#  'campbell',
#  'cicada',
#  'soiree',
#  'emilio',
#  'armstrong',
#  'lindsay',
#  'tuberculosis',
#  'terminable',
#  'cozen',
#  'creak',
#  'snapdragon',
#  'person',
#  'gustafson',
#  'howdy',
#  'rubble',
#  'poland',
#  'redden',
#  'byrd',
#  'aptitude',
#  'wallow',
#  'hamburg',
#  'salk',
#  'any',
#  'highlight',
#  'idolatry',
#  'impute',
#  'lausanne',
#  'downpour',
#  'finitude',
#  'tribal',
#  'guideline',
#  'jersey',
#  'anna',
#  'illogic',
#  'neurotic',
#  'ferocity',
#  'immutable',
#  'disruption',
#  'pepsi',
#  'bittern',
#  'anthropocentric',
#  'knobby',
#  'sanderling',
#  'odin',
#  'recife',
#  'jacket',
#  'salesgirl',
#  'grad',
#  'nozzle',
#  'misanthrope',
#  'zulu',
#  'tun',
#  'debauch',
#  'signify',
#  'cowpoke',
#  'fulcrum',
#  'waxen',
#  'copybook',
#  "she'd",
#  'vest',
#  'amphioxis',
#  'newark',
#  'wand',
#  'heterosexual',
#  'leprosy',
#  'lumbermen',
#  'dart',
#  'filial',
#  'dinnertime',
#  'supersede',
#  'extracellular',
#  'slope',
#  'lonesome',
#  'whippet',
#  'cavern',
#  'injunct',
#  'distraught',
#  'sowbug',
#  'wainscot',
#  'ok',
#  'pod',
#  'menlo',
#  'vibrant',
#  'corinthian',
#  'regimen',
#  'autosuggestible',
#  'terminus',
#  'shrilly',
#  'mincemeat',
#  'lymphoma',
#  'burg',
#  'euripides',
#  'streptomycin',
#  'bestirring',
#  'bilk',
#  'traitorous',
#  'fragmentation',
#  'dinosaur',
#  'shoestring',
#  'round',
#  'bedridden',
#  'prelude',
#  'tapa',
#  'flock',
#  'militia',
#  'extant',
#  'pluggable',
#  'earthenware',
#  'valletta',
#  'fondle',
#  'seen',
#  'malaysia',
#  'plop',
#  'peruvian',
#  'swollen',
#  'survivor',
#  'runt',
#  'gruesome',
#  'figurine',
#  'henchmen',
#  'vista',
#  'banana',
#  'ambrosia',
#  'superfluity',
#  'sanctuary',
#  'blue',
#  'tuba',
#  'slocum',
#  'talc',
#  'bleary',
#  'monochromator',
#  'coprocessor',
#  'isaiah',
#  'roomy',
#  'urinary',
#  'mcdowell',
#  'tacky',
#  'khaki',
#  'theoretician',
#  'embrace',
#  'limpid',
#  'laissez',
#  'rick',
#  'key',
#  'hydroxylate',
#  'peat',
#  'humiliate',
#  'guggenheim',
#  'ashore',
#  'speedy',
#  'induce',
#  'helmut',
#  'doomsday',
#  'piccolo',
#  'dietetic',
#  'falstaff',
#  'transplantation',
#  'cassava',
#  'provide',
#  'plaintive',
#  'procrastinate',
#  'minerva',
#  'anchorite',
#  'mercer',
#  'citron',
#  'appendix',
#  'hodges',
#  'ia',
#  'donna',
#  'jugate',
#  'tinkle',
#  'suction',
#  'hadrian',
#  'combinate',
#  'homonym',
#  'cravat',
#  'roundhouse',
#  'umbrage',
#  'chimera',
#  'oh',
#  'droplet',
#  'cockleshell',
#  'hit',
#  'load',
#  'frock',
#  'temptation',
#  'linear',
#  'wigmake',
#  'spent',
#  'exactitude',
#  'flounce',
#  'dewar',
#  'ovulate',
#  'column',
#  'mohr',
#  'lindbergh',
#  'mass',
#  'robust',
#  'hollingsworth',
#  'nanosecond',
#  'vaccine',
#  'bridget',
#  'tomb',
#  'perihelion',
#  'godwin',
#  'lotus',
#  'restorative',
#  'buffoon',
#  'frostbitten',
#  'anionic',
#  'specify',
#  'capital',
#  'convair',
#  'kite',
#  'plagiarist',
#  'dummy',
#  'potboil',
#  'congenital',
#  'viceroy',
#  'sweatshop',
#  'senate',
#  'bullseye',
#  'blanc',
#  'brick',
#  'thymus',
#  'vixen',
#  'archive',
#  'hatfield',
#  'paragonite',
#  'peppergrass',
#  'digest',
#  'mccoy',
#  'dater',
#  'wronskian',
#  'scaffold',
#  'temporary',
#  'ineradicable',
#  'holiday',
#  'nomad',
#  'longhorn',
#  'foote',
#  'found',
#  'shortfall',
#  'lobe',
#  'troll',
#  'erect',
#  "o's",
#  'hermes',
#  'handwrite',
#  'bundle',
#  'lady',
#  'mantissa',
#  'stunt',
#  'waterfront',
#  'crematory',
#  'netherlands',
#  'projector',
#  'drub',
#  'pierson',
#  'nagy',
#  'toni',
#  'cynthia',
#  'turnery',
#  'sweepstake',
#  'parentage',
#  'singleton',
#  'mention',
#  'padlock',
#  'simla',
#  'tariff',
#  'intonate',
#  'bellamy',
#  'bread',
#  'conspirator',
#  'tadpole',
#  'subjunctive',
#  'career',
#  'ivory',
#  'modulus',
#  'curate',
#  'autonomy',
#  'jupiter',
#  'rationale',
#  'stanford',
#  'hilt',
#  'concert',
#  'bilateral',
#  'arteriole',
#  'byroad',
#  'kankakee',
#  'situate',
#  'crystalline',
#  'swizzle',
#  'garry',
#  'want',
#  'johanson',
#  'bun',
#  'sweetish',
#  'brandt',
#  'aspersion',
#  'frail',
#  'astray',
#  'meetinghouse',
#  'dis',
#  'samurai',
#  'terbium',
#  'patrilineage',
#  'hollandaise',
#  'beyond',
#  'domestic',
#  'hesitate',
#  'yamaha',
#  'simultaneity',
#  'proud',
#  'narbonne',
#  'coercive',
#  'freeman',
#  'forgave',
#  'whinny',
#  'whence',
#  'yond',
#  'scar',
#  'unipolar',
#  'vehement',
#  'jeffrey',
#  'warplane',
#  'guenther',
#  'selenite',
#  'pediatrician',
#  'zachary',
#  'gander',
#  'old',
#  'victory',
#  'external',
#  'signature',
#  'passenger',
#  'glamor',
#  'mynheer',
#  'lineup',
#  'isadore',
#  'agree',
#  'gleeful',
#  'lugging',
#  'cryptography',
#  'brandeis',
#  'mission',
#  'fluke',
#  'interrogate',
#  'infinitude',
#  'bing',
#  'extricate',
#  'landscape',
#  'dick',
#  'deportee',
#  'salem',
#  'succeed',
#  'automaton',
#  'loosestrife',
#  'hyperbolic',
#  'retrovision',
#  'rhapsodic',
#  'shiv',
#  'pond',
#  'morn',
#  'mercantile',
#  'crinkle',
#  'fortran',
#  'gar',
#  'bagatelle',
#  'pfennig',
#  'shakeable',
#  'polio',
#  'kitchenette',
#  'sledgehammer',
#  'leek',
#  'ransom',
#  'poesy',
#  'damnation',
#  'trifluoride',
#  'plaything',
#  'lantern',
#  'loanword',
#  'compartment',
#  'into',
#  'slurp',
#  'duck',
#  'effluvia',
#  'e.g',
#  'eli',
#  'lauren',
#  'valerie',
#  'trachea',
#  'pragmatist',
#  'buss',
#  'pavilion',
#  'uri',
#  'seclusion',
#  'sideline',
#  'core',
#  'thumbprint',
#  'wavy',
#  'pliocene',
#  'adposition',
#  'hancock',
#  'mauricio',
#  'chalmers',
#  'luis',
#  'competitor',
#  'had',
#  'homeomorphic',
#  'determinacy',
#  'daly',
#  'jitterbug',
#  'nostalgic',
#  'becky',
#  'match',
#  'deviant',
#  'wilful',
#  'rater',
#  'breech',
#  'fescue',
#  'twin',
#  'marital',
#  'preclude',
#  'autocollimate',
#  'barnstorm',
#  'vacuo',
#  'aqueous',
#  'destroy',
#  'pokerface',
#  'concentrate',
#  'forwent',
#  'rhodonite',
#  'frontiersman',
#  'airlift',
#  'meanwhile',
#  'greater',
#  'speciate',
#  'consequent',
#  'cling',
#  'thyratron',
#  'hippodrome',
#  'bank',
#  'scotia',
#  'groton',
#  'turbidity',
#  'mesquite',
#  'espouse',
#  'bungalow',
#  'chairperson',
#  'tenure',
#  'institute',
#  'transmute',
#  'solo',
#  'logan',
#  'corpuscular',
#  'affectionate',
#  'goat',
#  'weal',
#  'tahiti',
#  'decompose',
#  'meteorite',
#  'gobble',
#  'countenance',
#  'intersperse',
#  'torso',
#  'joaquin',
#  'paradigmatic',
#  'suffragette',
#  'hierarchy',
#  'adjudicate',
#  'angel',
#  'tutorial',
#  'infestation',
#  'mangy',
#  'shop',
#  'latinate',
#  'cosmology',
#  'compost',
#  'blunt',
#  'refutation',
#  'tidewater',
#  'inexpressible',
#  'houghton',
#  'simulcast',
#  'fit',
#  'alton',
#  'inordinate',
#  'teamwork',
#  'crime',
#  'boogie',
#  'yawn',
#  'cambridge',
#  'looseleaf',
#  'shrink',
#  'butterball',
#  'anecdotal',
#  'articulatory',
#  'rhyme',
#  'statue',
#  'tight',
#  'hydroelectric',
#  'trod',
#  'stigmata',
#  'shmuel',
#  'marquess',
#  'plead',
#  'scrapbook',
#  'ma',
#  'transplant',
#  'injury',
#  'panjandrum',
#  'sallow',
#  'galley',
#  'crypt',
#  'pram',
#  'cunning',
#  'min',
#  'groove',
#  'feedback',
#  'sicily',
#  'halo',
#  'abeyance',
#  'bootlegging',
#  'pompous',
#  'coal',
#  'steven',
#  'impediment',
#  'omnipresent',
#  'professorial',
#  'cremate',
#  'riot',
#  'caliber',
#  'flair',
#  'megabit',
#  'threefold',
#  'footbridge',
#  'danubian',
#  'ussr',
#  'fredericksburg',
#  'mozzarella',
#  'uplift',
#  'saul',
#  'monomial',
#  'zealous',
#  'shadbush',
#  'upwind',
#  'armadillo',
#  'budd',
#  'glyph',
#  'stiletto',
#  'floodlight',
#  'ace',
#  'praecox',
#  'february',
#  'bayda',
#  'copious',
#  'transpacific',
#  'basilica',
#  'loud',
#  'adoption',
#  'baleen',
#  'setscrew',
#  'hereof',
#  'elite',
#  'hickory',
#  'referred',
#  'kaufman',
#  'smell',
#  'blather',
#  'moe',
#  'copenhagen',
#  'atlanta',
#  'impress',
#  'benjamin',
#  'israel',
#  'pothole',
#  'scattergun',
#  'accuracy',
#  'pellet',
#  'mirage',
#  'hugging',
#  'scintillate',
#  'alpaca',
#  'bladdernut',
#  'abbreviate',
#  'yuh',
#  'epiphyseal',
#  'via',
#  'janus',
#  'siva',
#  'telescopic',
#  'coolant',
#  'galway',
#  'stamp',
#  'vancouver',
#  'thousand',
#  'qed',
#  'oint',
#  'riotous',
#  'sentiment',
#  'gasify',
#  'rifleman',
#  'ttl',
#  'lavabo',
#  'intrusion',
#  'switzer',
#  'gemsbok',
#  'annunciate',
#  'cavalcade',
#  'denunciate',
#  'hardcopy',
#  'quirk',
#  'quicksilver',
#  'arcane',
#  'carload',
#  'chopstick',
#  'chronology',
#  'teasel',
#  'mario',
#  'juridic',
#  'indeterminate',
#  'paul',
#  'miocene',
#  'mensuration',
#  'el',
#  'palpate',
#  'ouvre',
#  'transferee',
#  'sung',
#  'merle',
#  'perfidious',
#  'fest',
#  'syllabi',
#  'furnish',
#  'pork',
#  'neath',
#  'inflater',
#  'flocculate',
#  'contradict',
#  'smithy',
#  'capetown',
#  'oncoming',
#  'basso',
#  'wind',
#  'flirt',
#  'judicatory',
#  'platoon',
#  'ram',
#  'pew',
#  'anarch',
#  'guffaw',
#  'traitor',
#  'cider',
#  'jade',
#  'eyeball',
#  'raffish',
#  'snatch',
#  'romp',
#  'pushbutton',
#  'kinesic',
#  'windowsill',
#  'swoop',
#  'frill',
#  'selectric',
#  'steady',
#  'mew',
#  'kenyon',
#  'catalogue',
#  'cairo',
#  'rag',
#  'sextet',
#  'visual',
#  'fresh',
#  'bookshelves',
#  'exit',
#  'hosiery',
#  'whiteface',
#  'lucid',
#  'edmonds',
#  'sandblast',
#  'olivier',
#  'libidinous',
#  'saudi',
#  'resist',
#  'author',
#  'psychobiology',
#  'amity',
#  'arraign',
#  'family',
#  'valuate',
#  'northwestern',
#  'escrow',
#  'coldhearted',
#  'bolshevik',
#  'witty',
#  'protozoa',
#  'pastor',
#  'impromptu',
#  'sou',
#  'sancho',
#  'bilingual',
#  'blenheim',
#  'inglorious',
#  'barbital',
#  'elope',
#  'vail',
#  'perquisite',
#  'order',
#  'gave',
#  'masochism',
#  'crackle',
#  'waffle',
#  'beneficent',
#  'drosophila',
#  'forgettable',
#  'sanctimonious',
#  'malposed',
#  'buxom',
#  'dame',
#  'irresolution',
#  'malden',
#  'dig',
#  'sordid',
#  'anabel',
#  'vetch',
#  'deafen',
#  'historian',
#  'assimilable',
#  'mudd',
#  'expansive',
#  'hi',
#  'siamese',
#  'irreversible',
#  'tract',
#  'aurora',
#  'postcondition',
#  'doubt',
#  'genre',
#  'britannic',
#  'snick',
#  'facetious',
#  'governess',
#  'freedmen',
#  'lighthouse',
#  'sericulture',
#  'gazebo',
#  'headline',
#  'gaudy',
#  'dabble',
#  'charity',
#  'baptiste',
#  'levine',
#  'monarch',
#  'stratton',
#  'gravitate',
#  'declination',
#  'produce',
#  'fragile',
#  'kigali',
#  'harmonica',
#  'skit',
#  'only',
#  'coventry',
#  'possess',
#  'playoff',
#  'mushy',
#  'actinolite',
#  'circulatory',
#  'adair',
#  'playa',
#  'xylene',
#  'dispersion',
#  'auerbach',
#  'milton',
#  'schubert',
#  'cagey',
#  'prom',
#  'quagmire',
#  'schaefer',
#  'framework',
#  'steele',
#  'menelaus',
#  'cholesterol',
#  'caper',
#  'klystron',
#  'indeed',
#  'gao',
#  'exxon',
#  'confect',
#  'valeur',
#  'lopez',
#  'altar',
#  'chill',
#  'formidable',
#  'contagious',
#  'gambit',
#  'southern',
#  'delaney',
#  'kelley',
#  'pestilent',
#  'mudsling',
#  'ineffable',
#  'barton',
#  'forswore',
#  'sabotage',
#  'permission',
#  'ablate',
#  'regression',
#  'bona',
#  'stein',
#  'bermuda',
#  'pelican',
#  'tantalum',
#  'conjoint',
#  'loki',
#  'atypic',
#  'trisyllable',
#  'saran',
#  "it'd",
#  'rayleigh',
#  'suburbia',
#  'nibelung',
#  'electron',
#  'circlet',
#  'slim',
#  'galatea',
#  'supposition',
#  'crutch',
#  'shoot',
#  'warn',
#  'elbow',
#  'crisp',
#  'messenger',
#  'myocardium',
#  'deception',
#  'checkerboard',
#  'ocean',
#  'electrophoresis',
#  'guinea',
#  'mohammed',
#  'pity',
#  'imitable',
#  'leverage',
#  'carcinogenic',
#  'fulsome',
#  'johannes',
#  'prosecution',
#  'meiji',
#  'gore',
#  'propionate',
#  'existent',
#  'foundation',
#  'platitudinous',
#  'dayton',
#  'commonality',
#  'tritium',
#  'midwinter',
#  'logging',
#  'curlew',
#  'narragansett',
#  'acumen',
#  'somalia',
#  'baden',
#  'emendable',
#  'scourge',
#  'mervin',
#  'allergic',
#  'ecumenist',
#  'brimful',
#  'salamander',
#  'pyongyang',
#  'disputant',
#  'arpeggio',
#  'factual',
#  'sicklewort',
#  'indecisive',
#  'piety',
#  'dakar',
#  'ethel',
#  'trapezoidal',
#  'jones',
#  'thessaly',
#  'vestal',
#  'slater',
#  'septennial',
#  'derek',
#  'aarhus',
#  'guardhouse',
#  'pyroxene',
#  'cold',
#  'moire',
#  'repute',
#  'egotism',
#  'trawl',
#  'enzyme',
#  'rawhide',
#  'abhor',
#  'bureau',
#  'david',
#  'peak',
#  'eightfold',
#  'conjoin',
#  'leland',
#  'samba',
#  'vocabulary',
#  'scrutable',
#  'sommerfeld',
#  'saratoga',
#  'pinochle',
#  'lucas',
#  'lifeguard',
#  'storytelling',
#  'disparage',
#  'codetermine',
#  'symbiotic',
#  'sloth',
#  'vial',
#  'uruguay',
#  'dusty',
#  'sawtooth',
#  'fallible',
#  'self',
#  'locomotory',
#  'pleat',
#  'ncr',
#  'apache',
#  'frazzle',
#  'electorate',
#  'kay',
#  'fricative',
#  'december',
#  'thule',
#  'farfetched',
#  'circumcision',
#  'steeve',
#  'nomograph',
#  'roguish',
#  'behave',
#  'latent',
#  ...}

# %%
"Bruce" in english_words
# Out:
# False

# %%
def get_signiture(word):
    return "".join(sorted(word))

# %%
get_signiture("brush")
# Out:
# 'bhrsu'

# %%
get_signiture("shrub")
# Out:
# 'bhrsu'

# %%
get_signiture("shrub") == get_signiture("brush")
# Out:
# True

# %%
def is_anagram(word_1:str, word_2:str) -> bool:
    return get_signiture(word_1) == get_signiture(word_2)

# %%
is_anagram("brush", "shrub")
# Out:
# True

# %%
from collections import defaultdict
anagram_lst = defaultdict(list)

# %%
for word in english_words:
    anagram = get_signiture(word)
    anagram_lst[anagram].append(word)

# %%
anagram_lst
# Out:
# defaultdict(list,
#             {'aku': ['auk'],
#              'knnow': ['known'],
#              'aber': ['brae', 'bear', 'bare'],
#              'aeeimprt': ['imperate'],
#              'aabcddorr': ['cardboard'],
#              'ceimostuv': ['muscovite'],
#              'aadeinrst': ['steradian'],
#              'aeekllst': ['skeletal'],
#              'eillmpttu': ['multiplet'],
#              'bdir': ['bird', 'drib'],
#              'eipr': ['pier', 'ripe'],
#              'chiint': ['chitin'],
#              'eeiprr': ['pierre'],
#              'cciilmopty': ['complicity'],
#              'bnnrstuu': ['sunburnt'],
#              'abcellrsw': ['screwball'],
#              'aegnr': ['range', 'anger'],
#              'atu': ['tau'],
#              'aeeglssy': ['eyeglass'],
#              'eeginpsttty': ['typesetting'],
#              'cehimnor': ['nichrome'],
#              'cddeoorw': ['codeword'],
#              'aeelnrtv': ['relevant'],
#              'bdiln': ['blind'],
#              'acghmrt': ['mcgrath'],
#              'ainr': ['rain', 'iran', 'nair'],
#              'deeils': ['diesel', 'seidel'],
#              'cklo': ['lock'],
#              'aachhilmopty': ['hypothalamic'],
#              'adeeimrsst': ['streamside'],
#              'ceeeeiinnprx': ['inexperience'],
#              'abcfikll': ['backfill'],
#              'efo': ['foe'],
#              'abeefilrrtu': ['irrefutable'],
#              'dimopu': ['podium'],
#              'ggosy': ['soggy'],
#              'aaabccknsv': ['canvasback'],
#              'bdeikoors': ['brookside'],
#              'aeln': ['elan', 'neal', 'lane', 'lean', 'lena'],
#              'fir': ['fir'],
#              'aginnov': ['avignon'],
#              'dfilloot': ['floodlit'],
#              'ceelnrt': ['lectern'],
#              'eehlmmns': ['helmsmen'],
#              'abeeiilnqtu': ['inequitable'],
#              'acelot': ['locate'],
#              'achrt': ['chart'],
#              'dgilnow': ['dowling'],
#              'adhosw': ['shadow'],
#              'aelmorsstu': ['somersault'],
#              'ehlmmu': ['hummel'],
#              'abcjkoot': ['jackboot'],
#              'eprsttu': ['sputter'],
#              'emnoopsuy': ['eponymous'],
#              'adelpqruu': ['quadruple'],
#              'abbhsy': ['shabby'],
#              'aeinprrst': ['transpire'],
#              'billnoou': ['bouillon'],
#              'bbeilllu': ['bluebill'],
#              'adims': ['midas'],
#              'abcellmp': ['campbell'],
#              'aaccdi': ['cicada'],
#              'eeiors': ['soiree'],
#              'eiilmo': ['emilio'],
#              'agmnorrst': ['armstrong'],
#              'adilnsy': ['lindsay'],
#              'bceilorsstuu': ['tuberculosis'],
#              'abeeilmnrt': ['terminable'],
#              'cenoz': ['cozen'],
#              'acekr': ['creak'],
#              'aadgnnoprs': ['snapdragon'],
#              'enoprs': ['person', 'posner'],
#              'afgnosstu': ['gustafson'],
#              'dhowy': ['howdy'],
#              'bbelru': ['rubble'],
#              'adlnop': ['poland'],
#              'ddeenr': ['redden'],
#              'bdry': ['byrd'],
#              'adeipttu': ['aptitude'],
#              'alloww': ['wallow'],
#              'abghmru': ['hamburg'],
#              'akls': ['salk'],
#              'any': ['any', 'nay'],
#              'gghhhiilt': ['highlight'],
#              'adilorty': ['idolatry', 'dilatory'],
#              'eimptu': ['impute'],
#              'aaelnnsu': ['lausanne'],
#              'dnoopruw': ['downpour'],
#              'defiintu': ['finitude'],
#              'abilrt': ['tribal'],
#              'deegiilnu': ['guideline'],
#              'eejrsy': ['jersey'],
#              'aann': ['anna'],
#              'cgiillo': ['illogic'],
#              'ceinortu': ['neurotic'],
#              'cefiorty': ['ferocity'],
#              'abeilmmtu': ['immutable'],
#              'diinoprstu': ['disruption'],
#              'eipps': ['pepsi'],
#              'beinrtt': ['bittern', 'britten'],
#              'accehinnooprrtt': ['anthropocentric'],
#              'bbknoy': ['knobby'],
#              'adegilnnrs': ['sanderling'],
#              'dino': ['odin', 'indo'],
#              'ceefir': ['recife', 'fierce'],
#              'acejkt': ['jacket'],
#              'aegillrss': ['salesgirl'],
#              'adgr': ['grad', 'drag'],
#              'elnozz': ['nozzle'],
#              'aehimnoprst': ['misanthrope'],
#              'luuz': ['zulu'],
#              'ntu': ['tun', 'nut'],
#              'abcdehu': ['debauch'],
#              'fgiinsy': ['signify'],
#              'cekoopw': ['cowpoke'],
#              'cflmruu': ['fulcrum'],
#              'aenwx': ['waxen'],
#              'bckooopy': ['copybook'],
#              "'dehs": ["she'd"],
#              'estv': ['vest'],
#              'ahiimopsx': ['amphioxis'],
#              'aeknrw': ['newark'],
#              'adnw': ['wand', 'dawn'],
#              'aeeehlorstux': ['heterosexual'],
#              'eloprsy': ['leprosy'],
#              'beelmmnru': ['lumbermen'],
#              'adrt': ['dart'],
#              'afiill': ['filial'],
#              'deeiimnnrt': ['dinnertime'],
#              'deeeprssu': ['supersede'],
#              'aaceelllrrtux': ['extracellular'],
#              'elops': ['slope'],
#              'eelmnoos': ['lonesome'],
#              'ehipptw': ['whippet'],
#              'acenrv': ['cavern', 'craven', 'carven'],
#              'cijnntu': ['injunct'],
#              'adghirsttu': ['distraught'],
#              'bgosuw': ['sowbug'],
#              'acinostw': ['wainscot'],
#              'ko': ['ok'],
#              'dop': ['pod'],
#              'elmno': ['menlo', 'monel', 'melon', 'lemon'],
#              'abinrtv': ['vibrant'],
#              'achiinnort': ['corinthian'],
#              'eegimnr': ['regimen'],
#              'abeeggilossttuu': ['autosuggestible'],
#              'eimnrstu': ['terminus'],
#              'hillrsy': ['shrilly'],
#              'aceeimmnt': ['mincemeat'],
#              'ahlmmopy': ['lymphoma'],
#              'bgru': ['burg', 'grub'],
#              'deeiiprsu': ['euripides'],
#              'ceimnoprstty': ['streptomycin'],
#              'begiinrrst': ['bestirring'],
#              'bikl': ['bilk'],
#              'aioorrsttu': ['traitorous'],
#              'aaefgimnnortt': ['fragmentation'],
#              'adinorsu': ['dinosaur'],
#              'eghinorsst': ['shoestring'],
#              'dnoru': ['round'],
#              'bdddeeinr': ['bedridden'],
#              'deelpru': ['prelude'],
#              'aapt': ['tapa'],
#              'cfklo': ['flock'],
#              'aiiilmt': ['militia'],
#              'aenttx': ['extant'],
#              'abeggllpu': ['pluggable'],
#              'aaeeehnrrtw': ['earthenware'],
#              'aaellttv': ['valletta'],
#              'deflno': ['fondle'],
#              'eens': ['seen'],
#              'aaailmsy': ['malaysia'],
#              'lopp': ['plop'],
#              'aeinpruv': ['peruvian'],
#              'ellnosw': ['swollen'],
#              'iorrsuvv': ['survivor'],
#              'nrtu': ['runt', 'turn'],
#              'eegmorsu': ['gruesome'],
#              'efgiinru': ['figurine'],
#              'ceehhmnn': ['henchmen'],
#              'aistv': ['vista'],
#              'aaabnn': ['banana'],
#              'aabimors': ['ambrosia'],
#              'efilprstuuy': ['superfluity'],
#              'aacnrstuy': ['sanctuary'],
#              'belu': ['blue'],
#              'abtu': ['tuba', 'abut', 'tabu'],
#              'clmosu': ['slocum'],
#              'aclt': ['talc'],
#              'abelry': ['bleary', 'barley'],
#              'achmmnoooorrt': ['monochromator'],
#              'cceoooprrss': ['coprocessor'],
#              'aahiis': ['isaiah'],
#              'moory': ['roomy'],
#              'ainrruy': ['urinary'],
#              'cdellmow': ['mcdowell'],
#              'ackty': ['tacky'],
#              'ahikk': ['khaki'],
#              'aceehiinortt': ['theoretician'],
#              'abceemr': ['embrace'],
#              'diilmp': ['limpid'],
#              'aeilssz': ['laissez'],
#              'cikr': ['rick'],
#              'eky': ['key'],
#              'adehlortxyy': ['hydroxylate'],
#              'aept': ['peat', 'tape', 'pate'],
#              'aehiilmtu': ['humiliate'],
#              'eeggghimnu': ['guggenheim'],
#              'aehors': ['ashore', 'hoarse'],
#              'deepsy': ['speedy'],
#              'cdeinu': ['induce'],
#              'ehlmtu': ['helmut'],
#              'addmoosy': ['doomsday'],
#              'cciloop': ['piccolo'],
#              'cdeeiitt': ['dietetic'],
#              'aaffflst': ['falstaff'],
#              'aaailnnnoprsttt': ['transplantation'],
#              'aaacssv': ['cassava'],
#              'deioprv': ['provide'],
#              'aeiilnptv': ['plaintive'],
#              'aaceinoprrstt': ['procrastinate'],
#              'aeimnrv': ['minerva'],
#              'acehinort': ['anchorite'],
#              'ceemrr': ['mercer'],
#              'cinort': ['citron'],
#              'adeinppx': ['appendix'],
#              'deghos': ['hodges'],
#              'ai': ['ia'],
#              'adnno': ['donna'],
#              'aegjtu': ['jugate'],
#              'eiklnt': ['tinkle'],
#              'cinostu': ['suction'],
#              'aadhinr': ['hadrian'],
#              'abceimnot': ['combinate'],
#              'hmmnooy': ['homonym'],
#              'aacrtv': ['cravat'],
#              'dehnoorsuu': ['roundhouse'],
#              'abegmru': ['umbrage'],
#              'acehimr': ['chimera'],
#              'ho': ['oh', 'ho'],
#              'deloprt': ['droplet'],
#              'cceehklllos': ['cockleshell'],
#              'hit': ['hit'],
#              'adlo': ['load'],
#              'cfkor': ['frock'],
#              'aeimnopttt': ['temptation'],
#              'aeilnr': ['linear'],
#              'aegikmw': ['wigmake'],
#              'enpst': ['spent'],
#              'acdeeittux': ['exactitude'],
#              'ceflnou': ['flounce'],
#              'aderw': ['dewar'],
#              'aelotuv': ['ovulate'],
#              'clmnou': ['column'],
#              'hmor': ['mohr'],
#              'bdeghilnr': ['lindbergh'],
#              'amss': ['mass'],
#              'borstu': ['robust'],
#              'ghhillnoorstw': ['hollingsworth'],
#              'acdennnoos': ['nanosecond'],
#              'acceinv': ['vaccine'],
#              'bdegirt': ['bridget'],
#              'bmot': ['tomb'],
#              'eehiilnopr': ['perihelion'],
#              'dginow': ['godwin'],
#              'lostu': ['lotus'],
#              'aeeiorrsttv': ['restorative'],
#              'bffnoou': ['buffoon'],
#              'befinorsttt': ['frostbitten'],
#              'aciinno': ['anionic'],
#              'cefipsy': ['specify'],
#              'aacilpt': ['capital'],
#              'acinorv': ['convair'],
#              'eikt': ['kite'],
#              'aagiilprst': ['plagiarist'],
#              'dmmuy': ['dummy'],
#              'biloopt': ['potboil'],
#              'acegilnnot': ['congenital'],
#              'ceiorvy': ['viceroy'],
#              'aehopsstw': ['sweatshop'],
#              'aeenst': ['senate'],
#              'beellsuy': ['bullseye'],
#              'abcln': ['blanc'],
#              'bcikr': ['brick'],
#              'hmstuy': ['thymus'],
#              'einvx': ['vixen'],
#              'acehirv': ['archive'],
#              'adefhilt': ['hatfield'],
#              'aaeginoprt': ['paragonite'],
#              'aeegppprrss': ['peppergrass'],
#              'degist': ['digest'],
#              'ccmoy': ['mccoy'],
#              'adert': ['dater', 'trade', 'tread'],
#              'aiknnorsw': ['wronskian'],
#              'acdfflos': ['scaffold'],
#              'aemoprrty': ['temporary'],
#              'aabcdeeiilnr': ['ineradicable'],
#              'adhiloy': ['holiday'],
#              'admno': ['nomad', 'monad', 'damon'],
#              'ghlnnoor': ['longhorn'],
#              'efoot': ['foote'],
#              'dfnou': ['found'],
#              'afhllorst': ['shortfall'],
#              'belo': ['lobe', 'loeb', 'bole'],
#              'llort': ['troll'],
#              'ceert': ['erect', 'crete'],
#              "'os": ["o's"],
#              'eehmrs': ['hermes'],
#              'adehinrtw': ['handwrite'],
#              'bdelnu': ['bundle'],
#              'adly': ['lady', 'daly'],
#              'aaimnsst': ['mantissa'],
#              'nsttu': ['stunt'],
#              'aefnorrttw': ['waterfront'],
#              'acemorrty': ['crematory'],
#              'adeehlnnrst': ['netherlands'],
#              'cejooprrt': ['projector'],
#              'bdru': ['drub'],
#              'einoprs': ['pierson'],
#              'agny': ['nagy', 'yang'],
#              'inot': ['toni', 'into', 'oint'],
#              'achinty': ['cynthia'],
#              'enrrtuy': ['turnery'],
#              'aeeekpsstw': ['sweepstake'],
#              'aaeegnprt': ['parentage'],
#              'egilnnost': ['singleton'],
#              'eimnnot': ['mention'],
#              'acdklop': ['padlock'],
#              'ailms': ['simla', 'islam'],
#              'affirt': ['tariff'],
#              'aeinnott': ['intonate'],
#              'abellmy': ['bellamy'],
#              'abder': ['bread', 'beard', 'debar', 'debra'],
#              'acinooprrst': ['conspirator'],
#              'adelopt': ['tadpole'],
#              'bceijnstuuv': ['subjunctive'],
#              'aceerr': ['career'],
#              'iorvy': ['ivory'],
#              'dlmosuu': ['modulus'],
#              'acertu': ['curate'],
#              'amnootuy': ['autonomy'],
#              'eijprtu': ['jupiter'],
#              'aaeilnort': ['rationale'],
#              'adfnorst': ['stanford'],
#              'hilt': ['hilt'],
#              'ccenort': ['concert'],
#              'aabeillrt': ['bilateral'],
#              'aeeilorrt': ['arteriole'],
#              'abdory': ['byroad'],
#              'aaeekkkn': ['kankakee'],
#              'aeisttu': ['situate'],
#              'aceillnrsty': ['crystalline'],
#              'eilswzz': ['swizzle'],
#              'agrry': ['garry'],
#              'antw': ['want'],
#              'ahjnnoos': ['johanson'],
#              'bnu': ['bun'],
#              'eehisstw': ['sweetish'],
#              'abdnrt': ['brandt'],
#              'aeinoprss': ['aspersion'],
#              'afilr': ['frail', 'flair'],
#              'aarsty': ['astray'],
#              'eeeghimnostu': ['meetinghouse'],
#              'dis': ['dis'],
#              'aaimrsu': ['samurai'],
#              'beimrtu': ['terbium'],
#              'aaeegiilnprt': ['patrilineage'],
#              'aadehillnos': ['hollandaise'],
#              'bdenoy': ['beyond'],
#              'cdeimost': ['domestic'],
#              'aeehistt': ['hesitate'],
#              'aaahmy': ['yamaha'],
#              'aeiilmnsttuy': ['simultaneity'],
#              'dopru': ['proud'],
#              'abennnor': ['narbonne'],
#              'cceeiorv': ['coercive'],
#              'aeefmnr': ['freeman'],
#              'aefgorv': ['forgave'],
#              'hinnwy': ['whinny'],
#              'ceehnw': ['whence'],
#              'dnoy': ['yond'],
#              'acrs': ['scar'],
#              'ailnopru': ['unipolar'],
#              'eeehmntv': ['vehement'],
#              'eeffjry': ['jeffrey'],
#              'aaelnprw': ['warplane'],
#              'eeghnrtu': ['guenther'],
#              'eeeilnst': ['selenite'],
#              'aacdeiiinprt': ['pediatrician'],
#              'aachryz': ['zachary'],
#              'adegnr': ['gander', 'danger', 'garden'],
#              'dlo': ['old'],
#              'ciortvy': ['victory'],
#              'aeelnrtx': ['external'],
#              'aeginrstu': ['signature'],
#              'aeegnprss': ['passenger'],
#              'aglmor': ['glamor'],
#              'eehmnry': ['mynheer'],
#              'eilnpu': ['lineup', 'lupine'],
#              'adeiors': ['isadore'],
#              'aeegr': ['agree', 'eager'],
#              'eefgllu': ['gleeful'],
#              'gggilnu': ['lugging'],
#              'acghopprrtyy': ['cryptography'],
#              'abdeinrs': ['brandeis'],
#              'iimnoss': ['mission'],
#              'efklu': ['fluke'],
#              'aeeginorrtt': ['interrogate'],
#              'defiiinntu': ['infinitude'],
#              'bgin': ['bing'],
#              'aceeirttx': ['extricate'],
#              'aacdelnps': ['landscape'],
#              'cdik': ['dick'],
#              'deeeoprt': ['deportee'],
#              'aelms': ['salem', 'selma'],
#              'ccdeesu': ['succeed'],
#              'aamnoottu': ['automaton'],
#              'eefiloorsst': ['loosestrife'],
#              'bcehilopry': ['hyperbolic'],
#              'eiinoorrstv': ['retrovision'],
#              'acdhioprs': ['rhapsodic'],
#              'hisv': ['shiv'],
#              'dnop': ['pond'],
#              'mnor': ['morn', 'norm'],
#              'aceeilmnrt': ['mercantile'],
#              'ceiklnr': ['crinkle'],
#              'afnorrt': ['fortran'],
#              'agr': ['gar', 'rag'],
#              'aabeegllt': ['bagatelle'],
#              'efginnp': ['pfennig'],
#              'aabeehkls': ['shakeable'],
#              'iloop': ['polio'],
#              'ceeehiknttt': ['kitchenette'],
#              'adeeeghlmmrs': ['sledgehammer'],
#              'eekl': ['leek', 'keel'],
#              'amnors': ['ransom'],
#              'eopsy': ['poesy', 'sepoy', 'posey'],
#              'aadimnnot': ['damnation'],
#              'defiilorrtu': ['trifluoride'],
#              'aghilnpty': ['plaything'],
#              'aelnnrt': ['lantern'],
#              'adlnoorw': ['loanword'],
#              'acemmnoprtt': ['compartment'],
#              'lprsu': ['slurp'],
#              'cdku': ['duck'],
#              'aeffiluv': ['effluvia'],
#              '.eg': ['e.g'],
#              'eil': ['eli', 'lie'],
#              'aelnru': ['lauren', 'neural'],
#              'aeeilrv': ['valerie'],
#              'aacehrt': ['trachea'],
#              'aagimprstt': ['pragmatist'],
#              'bssu': ['buss'],
#              'aiilnopv': ['pavilion'],
#              'iru': ['uri'],
#              'ceilnossu': ['seclusion'],
#              'deeiilns': ['sideline'],
#              'ceor': ['core'],
#              'bhimnprttu': ['thumbprint'],
#              'avwy': ['wavy'],
#              'ceeilnop': ['pliocene'],
#              'adiinoopst': ['adposition'],
#              'acchkno': ['hancock'],
#              'aciimoru': ['mauricio'],
#              'acehlmrs': ['chalmers'],
#              'ilsu': ['luis'],
#              'ceimooprtt': ['competitor'],
#              'adh': ['had'],
#              'cehhimmooopr': ['homeomorphic'],
#              'acdeeimnrty': ['determinacy'],
#              'begijrttu': ['jitterbug'],
#              'acgilnost': ['nostalgic'],
#              'bceky': ['becky'],
#              'achmt': ['match'],
#              'adeintv': ['deviant'],
#              'filluw': ['wilful'],
#              'aerrt': ['rater', 'terra'],
#              'bceehr': ['breech'],
#              'ceefsu': ['fescue'],
#              'intw': ['twin'],
#              'aailmrt': ['marital', 'martial'],
#              'cdeelpru': ['preclude'],
#              'aaceillmoottu': ['autocollimate'],
#              'abmnorrst': ['barnstorm'],
#              'acouv': ['vacuo'],
#              'aeoqsuu': ['aqueous'],
#              'deorsty': ['destroy'],
#              'aceefkopr': ['pokerface'],
#              'acceennortt': ['concentrate'],
#              'efnortw': ['forwent'],
#              'dehinoort': ['rhodonite'],
#              'aefimnnorrst': ['frontiersman'],
#              'afiilrt': ['airlift'],
#              'aeehilmnw': ['meanwhile'],
#              'aeegrrt': ['greater'],
#              'aceeipst': ['speciate'],
#              'ceennoqstu': ['consequent'],
#              'cgiln': ['cling'],
#              'ahnorrtty': ['thyratron'],
#              'dehimooppr': ['hippodrome'],
#              'abkn': ['bank'],
#              'aciost': ['scotia'],
#              'gnoort': ['groton', 'gorton'],
#              'bdiirttuy': ['turbidity'],
#              'eeimqstu': ['mesquite'],
#              'eeopssu': ['espouse'],
#              'abglnouw': ['bungalow'],
#              'acehinoprrs': ['chairperson'],
#              'eenrtu': ['tenure', 'neuter'],
#              'eiinstttu': ['institute'],
#              'aemnrsttu': ['transmute'],
#              'loos': ['solo', 'oslo'],
#              'aglno': ['logan', 'along', 'anglo'],
#              'accloprrsuu': ['corpuscular'],
#              'aaceeffinott': ['affectionate'],
#              'agot': ['goat'],
#              'aelw': ['weal', 'wale'],
#              'ahiitt': ['tahiti'],
#              'cdeemoops': ['decompose'],
#              'eeeimortt': ['meteorite'],
#              'bbeglo': ['gobble'],
#              'acceennnotu': ['countenance'],
#              'eeeinprrsst': ['intersperse'],
#              'oorst': ['torso', 'roost'],
#              'aijnoqu': ['joaquin'],
#              'aaacdgiimprt': ['paradigmatic'],
#              'aeeffgrsttu': ['suffragette'],
#              'acehhirry': ['hierarchy'],
#              'aacddeijtu': ['adjudicate'],
#              'aegln': ['angel', 'lange', 'angle', 'glean', 'galen'],
#              'ailorttu': ['tutorial'],
#              'aefiinnostt': ['infestation'],
#              'agmny': ['mangy'],
#              'hops': ['shop', 'posh'],
#              'aaeilntt': ['latinate'],
#              'cglmooosy': ['cosmology'],
#              'cmoopst': ['compost'],
#              'blntu': ['blunt'],
#              'aefinorttu': ['refutation'],
#              'adeeirttw': ['tidewater'],
#              'beeeiilnprssx': ['inexpressible'],
#              'ghhnootu': ['houghton'],
#              'acilmsstu': ['simulcast'],
#              'fit': ['fit'],
#              'alnot': ['alton', 'talon', 'tonal'],
#              'adeiinnort': ['inordinate'],
#              'aekmortw': ['teamwork'],
#              'ceimr': ['crime'],
#              'begioo': ['boogie'],
#              'anwy': ['yawn'],
#              'abcdegimr': ['cambridge'],
#              'aeeflloos': ['looseleaf'],
#              'hiknrs': ['shrink'],
#              'abbellrttu': ['butterball'],
#              'aacdelnot': ['anecdotal'],
#              'aacilorrttuy': ['articulatory'],
#              'ehmry': ['rhyme'],
#              'aesttu': ['statue', 'astute'],
#              'ghitt': ['tight'],
#              'ccdeehilorrty': ['hydroelectric'],
#              'dort': ['trod'],
#              'aagimstt': ['stigmata', 'astigmat'],
#              'ehlmsu': ['shmuel'],
#              'aemqrssu': ['marquess'],
#              'adelp': ['plead', 'pedal'],
#              'abckooprs': ['scrapbook'],
#              'am': ['ma', 'am'],
#              'aalnnprstt': ['transplant'],
#              'ijnruy': ['injury'],
#              'aadjmnnpru': ['panjandrum'],
#              'allosw': ['sallow'],
#              'aeglly': ['galley'],
#              'cprty': ['crypt'],
#              'ampr': ['pram', 'ramp'],
#              'cginnnu': ['cunning'],
#              'imn': ['min'],
#              'egoorv': ['groove'],
#              'abcdeefk': ['feedback'],
#              'ciilsy': ['sicily'],
#              'ahlo': ['halo'],
#              'aabceeny': ['abeyance'],
#              'begggilnoot': ['bootlegging'],
#              'mooppsu': ['pompous'],
#              'aclo': ['coal', 'cola'],
#              'eenstv': ['steven'],
#              'deeiimmnpt': ['impediment'],
#              'eeimnnoprst': ['omnipresent'],
#              'aefilooprrss': ['professorial'],
#              'aceemrt': ['cremate'],
#              'iort': ['riot', 'tori', 'trio'],
#              'abceilr': ['caliber', 'calibre'],
#              'abegimt': ['megabit'],
#              'deefhlort': ['threefold'],
#              'bdefgioort': ['footbridge'],
#              'aabdinnu': ['danubian'],
#              'rssu': ['ussr', 'russ'],
#              'bcdeefgikrrrsu': ['fredericksburg'],
#              'aaellmorzz': ['mozzarella'],
#              'filptu': ['uplift'],
#              'alsu': ['saul'],
#              'ailmmnoo': ['monomial'],
#              'aelosuz': ['zealous'],
#              'abdhhssu': ['shadbush'],
#              'dinpuw': ['upwind', 'windup'],
#              'aadillmor': ['armadillo'],
#              'bddu': ['budd'],
#              'ghlpy': ['glyph'],
#              'eilosttt': ['stiletto'],
#              'dfghilloot': ['floodlight'],
#              'ace': ['ace'],
#              'aceoprx': ['praecox'],
#              'abefrruy': ['february'],
#              'aabdy': ['bayda'],
#              'cioopsu': ['copious'],
#              'aaccfiinprst': ['transpacific'],
#              'aabciils': ['basilica'],
#              'dlou': ['loud'],
#              'adinoopt': ['adoption'],
#              'abeeln': ['baleen'],
#              'ceersstw': ['setscrew'],
#              'eefhor': ['hereof'],
#              'eeilt': ['elite'],
#              'chikory': ['hickory'],
#              'deeefrrr': ['referred'],
#              'aafkmnu': ['kaufman'],
#              'ellms': ['smell'],
#              'abehlrt': ['blather'],
#              'emo': ['moe'],
#              'aceeghnnop': ['copenhagen'],
#              'aaalntt': ['atlanta'],
#              'eimprss': ['impress'],
#              'abeijmnn': ['benjamin'],
#              'aeilrs': ['israel', 'serial'],
#              'ehloopt': ['pothole'],
#              'acegnrsttu': ['scattergun'],
#              'aacccruy': ['accuracy'],
#              'eellpt': ['pellet'],
#              'aegimr': ['mirage'],
#              'ggghinu': ['hugging'],
#              'aceiillnstt': ['scintillate'],
#              'aaaclp': ['alpaca'],
#              'abddelnrtu': ['bladdernut'],
#              'aabbeeirtv': ['abbreviate'],
#              'huy': ['yuh'],
#              'aeehilppsy': ['epiphyseal'],
#              'aiv': ['via'],
#              'ajnsu': ['janus'],
#              'aisv': ['siva', 'avis', 'visa'],
#              'cceeilopst': ['telescopic'],
#              'aclnoot': ['coolant'],
#              'aaglwy': ['galway'],
#              'ampst': ['stamp'],
#              'acenoruvv': ['vancouver'],
#              'adhnostu': ['thousand'],
#              'deq': ['qed'],
#              'ioorstu': ['riotous'],
#              'eeimnnstt': ['sentiment'],
#              'afgisy': ['gasify'],
#              'aefilmnr': ['rifleman'],
#              'ltt': ['ttl'],
#              'aablov': ['lavabo'],
#              'iinnorstu': ['intrusion'],
#              'eirstwz': ['switzer'],
#              'begkmos': ['gemsbok'],
#              'aaceinnntu': ['annunciate'],
#              'aaaccdelv': ['cavalcade'],
#              'acdeeinntu': ['denunciate'],
#              'acdhopry': ['hardcopy'],
#              'ikqru': ['quirk'],
#              'ceiiklqrsuv': ['quicksilver'],
#              'aacenr': ['arcane'],
#              'aacdlor': ['carload'],
#              'cchikopst': ['chopstick'],
#              'cghlnooory': ['chronology'],
#              'aeelst': ['teasel'],
#              'aimor': ['mario', 'maori'],
#              'cdiijru': ['juridic'],
#              'adeeeiimnnrtt': ['indeterminate'],
#              'alpu': ['paul'],
#              'ceeimno': ['miocene'],
#              'aeimnnorstu': ['mensuration'],
#              'el': ['el'],
#              'aaelppt': ['palpate'],
#              'eoruv': ['ouvre'],
#              'aeeefnrrst': ['transferee'],
#              'gnsu': ['sung', 'snug'],
#              'eelmr': ['merle', 'elmer'],
#              'defiioprsu': ['perfidious'],
#              'efst': ['fest'],
#              'abillsy': ['syllabi'],
#              'fhinrsu': ['furnish'],
#              'kopr': ['pork'],
#              'aehnt': ['neath', 'ethan'],
#              'aefilnrt': ['inflater'],
#              'accefllotu': ['flocculate'],
#              'accdinortt': ['contradict'],
#              'himsty': ['smithy'],
#              'acenoptw': ['capetown'],
#              'cgimnnoo': ['oncoming', 'gnomonic'],
#              'aboss': ['basso'],
#              'dinw': ['wind'],
#              'filrt': ['flirt'],
#              'acdijortuy': ['judicatory'],
#              'alnoopt': ['platoon'],
#              'amr': ['ram', 'mar', 'arm'],
#              'epw': ['pew'],
#              'aachnr': ['anarch'],
#              'affguw': ['guffaw'],
#              'aiorrtt': ['traitor'],
#              'cdeir': ['cider'],
#              'adej': ['jade', 'deja'],
#              'abeelly': ['eyeball'],
#              'affhirs': ['raffish'],
#              'achnst': ['snatch', 'stanch'],
#              'mopr': ['romp', 'prom'],
#              'bhnopsttuu': ['pushbutton'],
#              'ceiikns': ['kinesic'],
#              'diillnosww': ['windowsill'],
#              'oopsw': ['swoop'],
#              'fillr': ['frill'],
#              'cceeilrst': ['selectric'],
#              'adesty': ['steady'],
#              'emw': ['mew'],
#              'eknnoy': ['kenyon'],
#              'aaceglotu': ['catalogue', 'coagulate'],
#              'acior': ['cairo'],
#              'eesttx': ['sextet'],
#              'ailsuv': ['visual'],
#              'efhrs': ['fresh'],
#              'beehkloossv': ['bookshelves'],
#              'eitx': ['exit'],
#              'ehiorsy': ['hosiery'],
#              'aceefhitw': ['whiteface'],
#              'cdilu': ['lucid'],
#              'ddemnos': ['edmonds', 'desmond'],
#              'aabdlnsst': ['sandblast'],
#              'eiilorv': ['olivier'],
#              'bdiiilnosu': ['libidinous'],
#              'adisu': ['saudi'],
#              'eirsst': ['resist', 'sister'],
#              'ahortu': ['author'],
#              'bcghilooopsyy': ['psychobiology'],
#              'aimty': ['amity'],
#              'aaginrr': ['arraign'],
#              'afilmy': ['family'],
#              'aaeltuv': ['valuate'],
#              'eehnnorrsttw': ['northwestern'],
#              'ceorsw': ['escrow'],
#              'acddeehlort': ['coldhearted'],
#              'behiklosv': ['bolshevik'],
#              'ittwy': ['witty'],
#              'aoooprtz': ['protozoa'],
#              'aoprst': ['pastor'],
#              'immopprtu': ['impromptu'],
#              'osu': ['sou'],
#              'achnos': ['sancho'],
#              'abgiillnu': ['bilingual'],
#              'beehilmn': ['blenheim'],
#              'giilnoorsu': ['inglorious'],
#              'aabbilrt': ['barbital'],
#              'eelop': ['elope'],
#              'ailv': ['vail', 'vial'],
#              'eeiipqrstu': ['perquisite'],
#              'deorr': ['order'],
#              'aegv': ['gave', 'vega'],
#              'achimmoss': ['masochism'],
#              'acceklr': ['crackle'],
#              'aefflw': ['waffle'],
#              'bceeefinnt': ['beneficent'],
#              'adhilooprs': ['drosophila'],
#              'abeefglortt': ['forgettable'],
#              'aciimnnoosstu': ['sanctimonious'],
#              'adelmops': ['malposed'],
#              'bmoux': ['buxom'],
#              'adem': ['dame', 'mead', 'made'],
#              'eiilnoorrstu': ['irresolution'],
#              'adelmn': ['malden'],
#              'dgi': ['dig'],
#              'ddiors': ['sordid'],
#              'aabeln': ['anabel'],
#              'cehtv': ['vetch'],
#              'adeefn': ['deafen'],
#              'ahiinorst': ['historian'],
#              'aabeiillmss': ['assimilable'],
#              'ddmu': ['mudd'],
#              'aeeinpsvx': ['expansive'],
#              'hi': ['hi'],
#              'aeeimss': ['siamese'],
#              'beeeiilrrrsv': ['irreversible'],
#              'acrtt': ['tract'],
#              'aaorru': ['aurora'],
#              'cdiinnooopstt': ['postcondition'],
#              'bdotu': ['doubt'],
#              'eegnr': ['genre', 'green'],
#              'abciinnrt': ['britannic'],
#              'cikns': ['snick'],
#              'acefiostu': ['facetious'],
#              'eegnorssv': ['governess'],
#              'deeefmnr': ['freedmen'],
#              'eghhilostu': ['lighthouse'],
#              'ceeilrrstuu': ['sericulture'],
#              'abegoz': ['gazebo'],
#              'adeehiln': ['headline'],
#              'adguy': ['gaudy'],
#              'abbdel': ['dabble'],
#              'achirty': ['charity'],
#              'abeipstt': ['baptiste'],
#              'eeilnv': ['levine'],
#              'achmnor': ['monarch'],
#              'anorsttt': ['stratton'],
#              'aaegirttv': ['gravitate'],
#              'acdeiilnnot': ['declination'],
#              'cdeopru': ['produce'],
#              'aefgilr': ['fragile'],
#              'agiikl': ['kigali'],
#              'aachimnor': ['harmonica'],
#              'ikst': ['skit'],
#              'lnoy': ['only', 'lyon'],
#              'cenortvy': ['coventry'],
#              'eopssss': ['possess'],
#              'afflopy': ['playoff'],
#              'hmsuy': ['mushy'],
#              'aceiilnott': ['actinolite'],
#              'accilorrtuy': ['circulatory'],
#              'aadir': ['adair'],
#              'aalpy': ['playa'],
#              'eelnxy': ['xylene'],
#              'deiinoprss': ['dispersion'],
#              'aabcehru': ['auerbach'],
#              'ilmnot': ['milton'],
#              'bcehrstu': ['schubert'],
#              'acegy': ['cagey'],
#              'aegimqru': ['quagmire'],
#              'aceefhrs': ['schaefer'],
#              'aefkmorrw': ['framework'],
#              'eeelst': ['steele'],
#              'aeelmnsu': ['menelaus'],
#              'ceehlloorst': ['cholesterol'],
#              'acepr': ['caper'],
#              'klnorsty': ['klystron'],
#              'ddeein': ['indeed'],
#              'ago': ['gao', 'ago', 'goa'],
#              'enoxx': ['exxon'],
#              'ccefnot': ['confect'],
#              'aelruv': ['valeur'],
#              'elopz': ['lopez'],
#              'aalrt': ['altar'],
#              'chill': ['chill'],
#              'abdefilmor': ['formidable'],
#              'acginoostu': ['contagious'],
#              'abgimt': ['gambit'],
#              'ehnorstu': ['southern'],
#              'adeelny': ['delaney'],
#              'eeklly': ['kelley'],
#              'eeilnpstt': ['pestilent'],
#              'dgilmnsu': ['mudsling'],
#              'abeeffiln': ['ineffable'],
#              'abnort': ['barton'],
#              'efoorrsw': ['forswore'],
#              'aabegost': ['sabotage'],
#              'eiimnoprss': ['permission', 'impression'],
#              'aabelt': ['ablate'],
#              'eeginorrss': ['regression'],
#              'abno': ['bona'],
#              'einst': ['stein', 'inset'],
#              'abdemru': ['bermuda'],
#              'aceilnp': ['pelican', 'panicle'],
#              'aalmnttu': ['tantalum'],
#              'cijnnoot': ['conjoint'],
#              'iklo': ['loki'],
#              'acipty': ['atypic'],
#              'abeilllrsty': ['trisyllable'],
#              'aanrs': ['saran'],
#              "'dit": ["it'd"],
#              'aeghilry': ['rayleigh'],
#              'abbirsuu': ['suburbia'],
#              'begilnnu': ['nibelung'],
#              'ceelnort': ['electron'],
#              'cceilrt': ['circlet'],
#              'ilms': ['slim'],
#              'aaaeglt': ['galatea'],
#              'iinooppsstu': ['supposition'],
#              'cchrtu': ['crutch'],
#              'hoost': ['shoot', 'sooth'],
#              'anrw': ['warn'],
#              'below': ['elbow', 'bowel', 'below'],
#              'ciprs': ['crisp'],
#              'eeegmnrss': ['messenger'],
#              'acdimmoruy': ['myocardium'],
#              'cdeeinopt': ['deception'],
#              'abccdeehkorr': ['checkerboard'],
#              'aceno': ['ocean', 'canoe'],
#              'ceeehilooprrsst': ['electrophoresis'],
#              'aeginu': ['guinea'],
#              'adehmmmo': ['mohammed'],
#              'ipty': ['pity'],
#              'abeiilmt': ['imitable'],
#              'aeeeglrv': ['leverage'],
#              'acccegiinnor': ['carcinogenic'],
#              'eflmosu': ['fulsome'],
#              'aehjnnos': ['johannes', 'johansen'],
#              'ceinooprstu': ['prosecution'],
#              'eiijm': ['meiji'],
#              'egor': ['gore', 'ogre'],
#              'aeinoopprt': ['propionate'],
#              'eeinsttx': ['existent'],
#              'adfinnootu': ['foundation'],
#              'adiilnopsttuu': ['platitudinous'],
#              'adnoty': ['dayton'],
#              'acilmmnooty': ['commonality'],
#              'iimrttu': ['tritium'],
#              'deiimnrtw': ['midwinter'],
#              'gggilno': ['logging'],
#              'celruw': ['curlew'],
#              'aaaegnnrrstt': ['narragansett'],
#              'acemnu': ['acumen'],
#              'aailmos': ['somalia'],
#              'abden': ['baden'],
#              'abdeeelmn': ['emendable'],
#              'cegorsu': ['scourge'],
#              'eimnrv': ['mervin', 'vermin'],
#              'acegillr': ['allergic'],
#              'ceeimnstu': ['ecumenist'],
#              'bfilmru': ['brimful'],
#              'aaadelmnrs': ['salamander'],
#              'aggnnopyy': ['pyongyang'],
#              'adinpsttu': ['disputant'],
#              'aeggiopr': ['arpeggio'],
#              'aacfltu': ['factual'],
#              'ceiklorstw': ['sicklewort'],
#              'cdeeiiinsv': ['indecisive'],
#              'eipty': ['piety'],
#              'aadkr': ['dakar'],
#              'eehlt': ['ethel', 'lethe'],
#              'aadeiloprtz': ['trapezoidal'],
#              'ejnos': ['jones'],
#              'aehlssty': ['thessaly'],
#              'aelstv': ['vestal'],
#              'aelrst': ['slater'],
#              'aeeilnnpst': ['septennial'],
#              'deekr': ['derek'],
#              'aahrsu': ['aarhus'],
#              'adeghorsuu': ['guardhouse'],
#              'eenoprxy': ['pyroxene'],
#              'cdlo': ['cold', 'clod'],
#              'eimor': ['moire'],
#              'eeprtu': ['repute'],
#              'egimost': ['egotism'],
#              'alrtw': ['trawl'],
#              'eemnyz': ['enzyme'],
#              'adehirw': ['rawhide'],
#              'abhor': ['abhor'],
#              'aberuu': ['bureau'],
#              'addiv': ['david'],
#              'aekp': ['peak'],
#              'defghilot': ['eightfold'],
#              'cijnnoo': ['conjoin'],
#              'adelln': ['leland'],
#              'aabms': ['samba'],
#              'aabcloruvy': ['vocabulary'],
#              'abcelrstu': ['scrutable'],
#              'deeflmmors': ['sommerfeld'],
#              'aaagorst': ['saratoga'],
#              'cehilnop': ['pinochle', 'phenolic'],
#              'aclsu': ['lucas', 'claus'],
#              'adefgilru': ['lifeguard'],
#              'egillnorstty': ['storytelling'],
#              'aadegiprs': ['disparage'],
#              'cdeeeimnort': ['codetermine'],
#              'bciimosty': ['symbiotic'],
#              'hlost': ['sloth', 'holst'],
#              'agruuuy': ['uruguay'],
#              'dstuy': ['dusty', 'study'],
#              'ahoosttw': ['sawtooth'],
#              'abefilll': ['fallible'],
#              'efls': ['self'],
#              'clmoooorty': ['locomotory'],
#              'aelpt': ['pleat', 'plate', 'leapt', 'petal'],
#              'cnr': ['ncr', 'nrc'],
#              'aacehp': ['apache'],
#              'aeflrzz': ['frazzle'],
#              'aceeelortt': ['electorate'],
#              'aky': ['kay', 'yak'],
#              'acefiirtv': ['fricative'],
#              'bcdeeemr': ['december'],
#              'ehltu': ['thule'],
#              'acdeeffhrt': ['farfetched'],
#              'ccciiimnorsu': ['circumcision'],
#              'eeestv': ['steeve'],
#              'aghmnoopr': ['nomograph'],
#              'ghiorsu': ['roguish'],
#              'abeehv': ['behave'],
#              'aelntt': ['latent', 'talent'],
#              'emrt': ['term'],
#              'aacrttt': ['attract'],
#              'abekr': ['brake', 'break'],
#              'eghhi': ['heigh'],
#              'cefflsu': ['scuffle'],
#              'eeiiqstux': ['exquisite'],
#              'ackls': ['slack'],
#              ...})

# %%
anagram_lst[get_signiture("shrub")]
# Out:
# ['shrub', 'brush']

# %%
# Counting

# %%
anagram_count = {anagram: len(anagram_lst) for anagram, anagram_lst in anagram_lst.items()}

# %%
anagram_count
# Out:
# {'aku': 1,
#  'knnow': 1,
#  'aber': 3,
#  'aeeimprt': 1,
#  'aabcddorr': 1,
#  'ceimostuv': 1,
#  'aadeinrst': 1,
#  'aeekllst': 1,
#  'eillmpttu': 1,
#  'bdir': 2,
#  'eipr': 2,
#  'chiint': 1,
#  'eeiprr': 1,
#  'cciilmopty': 1,
#  'bnnrstuu': 1,
#  'abcellrsw': 1,
#  'aegnr': 2,
#  'atu': 1,
#  'aeeglssy': 1,
#  'eeginpsttty': 1,
#  'cehimnor': 1,
#  'cddeoorw': 1,
#  'aeelnrtv': 1,
#  'bdiln': 1,
#  'acghmrt': 1,
#  'ainr': 3,
#  'deeils': 2,
#  'cklo': 1,
#  'aachhilmopty': 1,
#  'adeeimrsst': 1,
#  'ceeeeiinnprx': 1,
#  'abcfikll': 1,
#  'efo': 1,
#  'abeefilrrtu': 1,
#  'dimopu': 1,
#  'ggosy': 1,
#  'aaabccknsv': 1,
#  'bdeikoors': 1,
#  'aeln': 5,
#  'fir': 1,
#  'aginnov': 1,
#  'dfilloot': 1,
#  'ceelnrt': 1,
#  'eehlmmns': 1,
#  'abeeiilnqtu': 1,
#  'acelot': 1,
#  'achrt': 1,
#  'dgilnow': 1,
#  'adhosw': 1,
#  'aelmorsstu': 1,
#  'ehlmmu': 1,
#  'abcjkoot': 1,
#  'eprsttu': 1,
#  'emnoopsuy': 1,
#  'adelpqruu': 1,
#  'abbhsy': 1,
#  'aeinprrst': 1,
#  'billnoou': 1,
#  'bbeilllu': 1,
#  'adims': 1,
#  'abcellmp': 1,
#  'aaccdi': 1,
#  'eeiors': 1,
#  'eiilmo': 1,
#  'agmnorrst': 1,
#  'adilnsy': 1,
#  'bceilorsstuu': 1,
#  'abeeilmnrt': 1,
#  'cenoz': 1,
#  'acekr': 1,
#  'aadgnnoprs': 1,
#  'enoprs': 2,
#  'afgnosstu': 1,
#  'dhowy': 1,
#  'bbelru': 1,
#  'adlnop': 1,
#  'ddeenr': 1,
#  'bdry': 1,
#  'adeipttu': 1,
#  'alloww': 1,
#  'abghmru': 1,
#  'akls': 1,
#  'any': 2,
#  'gghhhiilt': 1,
#  'adilorty': 2,
#  'eimptu': 1,
#  'aaelnnsu': 1,
#  'dnoopruw': 1,
#  'defiintu': 1,
#  'abilrt': 1,
#  'deegiilnu': 1,
#  'eejrsy': 1,
#  'aann': 1,
#  'cgiillo': 1,
#  'ceinortu': 1,
#  'cefiorty': 1,
#  'abeilmmtu': 1,
#  'diinoprstu': 1,
#  'eipps': 1,
#  'beinrtt': 2,
#  'accehinnooprrtt': 1,
#  'bbknoy': 1,
#  'adegilnnrs': 1,
#  'dino': 2,
#  'ceefir': 2,
#  'acejkt': 1,
#  'aegillrss': 1,
#  'adgr': 2,
#  'elnozz': 1,
#  'aehimnoprst': 1,
#  'luuz': 1,
#  'ntu': 2,
#  'abcdehu': 1,
#  'fgiinsy': 1,
#  'cekoopw': 1,
#  'cflmruu': 1,
#  'aenwx': 1,
#  'bckooopy': 1,
#  "'dehs": 1,
#  'estv': 1,
#  'ahiimopsx': 1,
#  'aeknrw': 1,
#  'adnw': 2,
#  'aeeehlorstux': 1,
#  'eloprsy': 1,
#  'beelmmnru': 1,
#  'adrt': 1,
#  'afiill': 1,
#  'deeiimnnrt': 1,
#  'deeeprssu': 1,
#  'aaceelllrrtux': 1,
#  'elops': 1,
#  'eelmnoos': 1,
#  'ehipptw': 1,
#  'acenrv': 3,
#  'cijnntu': 1,
#  'adghirsttu': 1,
#  'bgosuw': 1,
#  'acinostw': 1,
#  'ko': 1,
#  'dop': 1,
#  'elmno': 4,
#  'abinrtv': 1,
#  'achiinnort': 1,
#  'eegimnr': 1,
#  'abeeggilossttuu': 1,
#  'eimnrstu': 1,
#  'hillrsy': 1,
#  'aceeimmnt': 1,
#  'ahlmmopy': 1,
#  'bgru': 2,
#  'deeiiprsu': 1,
#  'ceimnoprstty': 1,
#  'begiinrrst': 1,
#  'bikl': 1,
#  'aioorrsttu': 1,
#  'aaefgimnnortt': 1,
#  'adinorsu': 1,
#  'eghinorsst': 1,
#  'dnoru': 1,
#  'bdddeeinr': 1,
#  'deelpru': 1,
#  'aapt': 1,
#  'cfklo': 1,
#  'aiiilmt': 1,
#  'aenttx': 1,
#  'abeggllpu': 1,
#  'aaeeehnrrtw': 1,
#  'aaellttv': 1,
#  'deflno': 1,
#  'eens': 1,
#  'aaailmsy': 1,
#  'lopp': 1,
#  'aeinpruv': 1,
#  'ellnosw': 1,
#  'iorrsuvv': 1,
#  'nrtu': 2,
#  'eegmorsu': 1,
#  'efgiinru': 1,
#  'ceehhmnn': 1,
#  'aistv': 1,
#  'aaabnn': 1,
#  'aabimors': 1,
#  'efilprstuuy': 1,
#  'aacnrstuy': 1,
#  'belu': 1,
#  'abtu': 3,
#  'clmosu': 1,
#  'aclt': 1,
#  'abelry': 2,
#  'achmmnoooorrt': 1,
#  'cceoooprrss': 1,
#  'aahiis': 1,
#  'moory': 1,
#  'ainrruy': 1,
#  'cdellmow': 1,
#  'ackty': 1,
#  'ahikk': 1,
#  'aceehiinortt': 1,
#  'abceemr': 1,
#  'diilmp': 1,
#  'aeilssz': 1,
#  'cikr': 1,
#  'eky': 1,
#  'adehlortxyy': 1,
#  'aept': 3,
#  'aehiilmtu': 1,
#  'eeggghimnu': 1,
#  'aehors': 2,
#  'deepsy': 1,
#  'cdeinu': 1,
#  'ehlmtu': 1,
#  'addmoosy': 1,
#  'cciloop': 1,
#  'cdeeiitt': 1,
#  'aaffflst': 1,
#  'aaailnnnoprsttt': 1,
#  'aaacssv': 1,
#  'deioprv': 1,
#  'aeiilnptv': 1,
#  'aaceinoprrstt': 1,
#  'aeimnrv': 1,
#  'acehinort': 1,
#  'ceemrr': 1,
#  'cinort': 1,
#  'adeinppx': 1,
#  'deghos': 1,
#  'ai': 1,
#  'adnno': 1,
#  'aegjtu': 1,
#  'eiklnt': 1,
#  'cinostu': 1,
#  'aadhinr': 1,
#  'abceimnot': 1,
#  'hmmnooy': 1,
#  'aacrtv': 1,
#  'dehnoorsuu': 1,
#  'abegmru': 1,
#  'acehimr': 1,
#  'ho': 2,
#  'deloprt': 1,
#  'cceehklllos': 1,
#  'hit': 1,
#  'adlo': 1,
#  'cfkor': 1,
#  'aeimnopttt': 1,
#  'aeilnr': 1,
#  'aegikmw': 1,
#  'enpst': 1,
#  'acdeeittux': 1,
#  'ceflnou': 1,
#  'aderw': 1,
#  'aelotuv': 1,
#  'clmnou': 1,
#  'hmor': 1,
#  'bdeghilnr': 1,
#  'amss': 1,
#  'borstu': 1,
#  'ghhillnoorstw': 1,
#  'acdennnoos': 1,
#  'acceinv': 1,
#  'bdegirt': 1,
#  'bmot': 1,
#  'eehiilnopr': 1,
#  'dginow': 1,
#  'lostu': 1,
#  'aeeiorrsttv': 1,
#  'bffnoou': 1,
#  'befinorsttt': 1,
#  'aciinno': 1,
#  'cefipsy': 1,
#  'aacilpt': 1,
#  'acinorv': 1,
#  'eikt': 1,
#  'aagiilprst': 1,
#  'dmmuy': 1,
#  'biloopt': 1,
#  'acegilnnot': 1,
#  'ceiorvy': 1,
#  'aehopsstw': 1,
#  'aeenst': 1,
#  'beellsuy': 1,
#  'abcln': 1,
#  'bcikr': 1,
#  'hmstuy': 1,
#  'einvx': 1,
#  'acehirv': 1,
#  'adefhilt': 1,
#  'aaeginoprt': 1,
#  'aeegppprrss': 1,
#  'degist': 1,
#  'ccmoy': 1,
#  'adert': 3,
#  'aiknnorsw': 1,
#  'acdfflos': 1,
#  'aemoprrty': 1,
#  'aabcdeeiilnr': 1,
#  'adhiloy': 1,
#  'admno': 3,
#  'ghlnnoor': 1,
#  'efoot': 1,
#  'dfnou': 1,
#  'afhllorst': 1,
#  'belo': 3,
#  'llort': 1,
#  'ceert': 2,
#  "'os": 1,
#  'eehmrs': 1,
#  'adehinrtw': 1,
#  'bdelnu': 1,
#  'adly': 2,
#  'aaimnsst': 1,
#  'nsttu': 1,
#  'aefnorrttw': 1,
#  'acemorrty': 1,
#  'adeehlnnrst': 1,
#  'cejooprrt': 1,
#  'bdru': 1,
#  'einoprs': 1,
#  'agny': 2,
#  'inot': 3,
#  'achinty': 1,
#  'enrrtuy': 1,
#  'aeeekpsstw': 1,
#  'aaeegnprt': 1,
#  'egilnnost': 1,
#  'eimnnot': 1,
#  'acdklop': 1,
#  'ailms': 2,
#  'affirt': 1,
#  'aeinnott': 1,
#  'abellmy': 1,
#  'abder': 4,
#  'acinooprrst': 1,
#  'adelopt': 1,
#  'bceijnstuuv': 1,
#  'aceerr': 1,
#  'iorvy': 1,
#  'dlmosuu': 1,
#  'acertu': 1,
#  'amnootuy': 1,
#  'eijprtu': 1,
#  'aaeilnort': 1,
#  'adfnorst': 1,
#  'hilt': 1,
#  'ccenort': 1,
#  'aabeillrt': 1,
#  'aeeilorrt': 1,
#  'abdory': 1,
#  'aaeekkkn': 1,
#  'aeisttu': 1,
#  'aceillnrsty': 1,
#  'eilswzz': 1,
#  'agrry': 1,
#  'antw': 1,
#  'ahjnnoos': 1,
#  'bnu': 1,
#  'eehisstw': 1,
#  'abdnrt': 1,
#  'aeinoprss': 1,
#  'afilr': 2,
#  'aarsty': 1,
#  'eeeghimnostu': 1,
#  'dis': 1,
#  'aaimrsu': 1,
#  'beimrtu': 1,
#  'aaeegiilnprt': 1,
#  'aadehillnos': 1,
#  'bdenoy': 1,
#  'cdeimost': 1,
#  'aeehistt': 1,
#  'aaahmy': 1,
#  'aeiilmnsttuy': 1,
#  'dopru': 1,
#  'abennnor': 1,
#  'cceeiorv': 1,
#  'aeefmnr': 1,
#  'aefgorv': 1,
#  'hinnwy': 1,
#  'ceehnw': 1,
#  'dnoy': 1,
#  'acrs': 1,
#  'ailnopru': 1,
#  'eeehmntv': 1,
#  'eeffjry': 1,
#  'aaelnprw': 1,
#  'eeghnrtu': 1,
#  'eeeilnst': 1,
#  'aacdeiiinprt': 1,
#  'aachryz': 1,
#  'adegnr': 3,
#  'dlo': 1,
#  'ciortvy': 1,
#  'aeelnrtx': 1,
#  'aeginrstu': 1,
#  'aeegnprss': 1,
#  'aglmor': 1,
#  'eehmnry': 1,
#  'eilnpu': 2,
#  'adeiors': 1,
#  'aeegr': 2,
#  'eefgllu': 1,
#  'gggilnu': 1,
#  'acghopprrtyy': 1,
#  'abdeinrs': 1,
#  'iimnoss': 1,
#  'efklu': 1,
#  'aeeginorrtt': 1,
#  'defiiinntu': 1,
#  'bgin': 1,
#  'aceeirttx': 1,
#  'aacdelnps': 1,
#  'cdik': 1,
#  'deeeoprt': 1,
#  'aelms': 2,
#  'ccdeesu': 1,
#  'aamnoottu': 1,
#  'eefiloorsst': 1,
#  'bcehilopry': 1,
#  'eiinoorrstv': 1,
#  'acdhioprs': 1,
#  'hisv': 1,
#  'dnop': 1,
#  'mnor': 2,
#  'aceeilmnrt': 1,
#  'ceiklnr': 1,
#  'afnorrt': 1,
#  'agr': 2,
#  'aabeegllt': 1,
#  'efginnp': 1,
#  'aabeehkls': 1,
#  'iloop': 1,
#  'ceeehiknttt': 1,
#  'adeeeghlmmrs': 1,
#  'eekl': 2,
#  'amnors': 1,
#  'eopsy': 3,
#  'aadimnnot': 1,
#  'defiilorrtu': 1,
#  'aghilnpty': 1,
#  'aelnnrt': 1,
#  'adlnoorw': 1,
#  'acemmnoprtt': 1,
#  'lprsu': 1,
#  'cdku': 1,
#  'aeffiluv': 1,
#  '.eg': 1,
#  'eil': 2,
#  'aelnru': 2,
#  'aeeilrv': 1,
#  'aacehrt': 1,
#  'aagimprstt': 1,
#  'bssu': 1,
#  'aiilnopv': 1,
#  'iru': 1,
#  'ceilnossu': 1,
#  'deeiilns': 1,
#  'ceor': 1,
#  'bhimnprttu': 1,
#  'avwy': 1,
#  'ceeilnop': 1,
#  'adiinoopst': 1,
#  'acchkno': 1,
#  'aciimoru': 1,
#  'acehlmrs': 1,
#  'ilsu': 1,
#  'ceimooprtt': 1,
#  'adh': 1,
#  'cehhimmooopr': 1,
#  'acdeeimnrty': 1,
#  'begijrttu': 1,
#  'acgilnost': 1,
#  'bceky': 1,
#  'achmt': 1,
#  'adeintv': 1,
#  'filluw': 1,
#  'aerrt': 2,
#  'bceehr': 1,
#  'ceefsu': 1,
#  'intw': 1,
#  'aailmrt': 2,
#  'cdeelpru': 1,
#  'aaceillmoottu': 1,
#  'abmnorrst': 1,
#  'acouv': 1,
#  'aeoqsuu': 1,
#  'deorsty': 1,
#  'aceefkopr': 1,
#  'acceennortt': 1,
#  'efnortw': 1,
#  'dehinoort': 1,
#  'aefimnnorrst': 1,
#  'afiilrt': 1,
#  'aeehilmnw': 1,
#  'aeegrrt': 1,
#  'aceeipst': 1,
#  'ceennoqstu': 1,
#  'cgiln': 1,
#  'ahnorrtty': 1,
#  'dehimooppr': 1,
#  'abkn': 1,
#  'aciost': 1,
#  'gnoort': 2,
#  'bdiirttuy': 1,
#  'eeimqstu': 1,
#  'eeopssu': 1,
#  'abglnouw': 1,
#  'acehinoprrs': 1,
#  'eenrtu': 2,
#  'eiinstttu': 1,
#  'aemnrsttu': 1,
#  'loos': 2,
#  'aglno': 3,
#  'accloprrsuu': 1,
#  'aaceeffinott': 1,
#  'agot': 1,
#  'aelw': 2,
#  'ahiitt': 1,
#  'cdeemoops': 1,
#  'eeeimortt': 1,
#  'bbeglo': 1,
#  'acceennnotu': 1,
#  'eeeinprrsst': 1,
#  'oorst': 2,
#  'aijnoqu': 1,
#  'aaacdgiimprt': 1,
#  'aeeffgrsttu': 1,
#  'acehhirry': 1,
#  'aacddeijtu': 1,
#  'aegln': 5,
#  'ailorttu': 1,
#  'aefiinnostt': 1,
#  'agmny': 1,
#  'hops': 2,
#  'aaeilntt': 1,
#  'cglmooosy': 1,
#  'cmoopst': 1,
#  'blntu': 1,
#  'aefinorttu': 1,
#  'adeeirttw': 1,
#  'beeeiilnprssx': 1,
#  'ghhnootu': 1,
#  'acilmsstu': 1,
#  'fit': 1,
#  'alnot': 3,
#  'adeiinnort': 1,
#  'aekmortw': 1,
#  'ceimr': 1,
#  'begioo': 1,
#  'anwy': 1,
#  'abcdegimr': 1,
#  'aeeflloos': 1,
#  'hiknrs': 1,
#  'abbellrttu': 1,
#  'aacdelnot': 1,
#  'aacilorrttuy': 1,
#  'ehmry': 1,
#  'aesttu': 2,
#  'ghitt': 1,
#  'ccdeehilorrty': 1,
#  'dort': 1,
#  'aagimstt': 2,
#  'ehlmsu': 1,
#  'aemqrssu': 1,
#  'adelp': 2,
#  'abckooprs': 1,
#  'am': 2,
#  'aalnnprstt': 1,
#  'ijnruy': 1,
#  'aadjmnnpru': 1,
#  'allosw': 1,
#  'aeglly': 1,
#  'cprty': 1,
#  'ampr': 2,
#  'cginnnu': 1,
#  'imn': 1,
#  'egoorv': 1,
#  'abcdeefk': 1,
#  'ciilsy': 1,
#  'ahlo': 1,
#  'aabceeny': 1,
#  'begggilnoot': 1,
#  'mooppsu': 1,
#  'aclo': 2,
#  'eenstv': 1,
#  'deeiimmnpt': 1,
#  'eeimnnoprst': 1,
#  'aefilooprrss': 1,
#  'aceemrt': 1,
#  'iort': 3,
#  'abceilr': 2,
#  'abegimt': 1,
#  'deefhlort': 1,
#  'bdefgioort': 1,
#  'aabdinnu': 1,
#  'rssu': 2,
#  'bcdeefgikrrrsu': 1,
#  'aaellmorzz': 1,
#  'filptu': 1,
#  'alsu': 1,
#  'ailmmnoo': 1,
#  'aelosuz': 1,
#  'abdhhssu': 1,
#  'dinpuw': 2,
#  'aadillmor': 1,
#  'bddu': 1,
#  'ghlpy': 1,
#  'eilosttt': 1,
#  'dfghilloot': 1,
#  'ace': 1,
#  'aceoprx': 1,
#  'abefrruy': 1,
#  'aabdy': 1,
#  'cioopsu': 1,
#  'aaccfiinprst': 1,
#  'aabciils': 1,
#  'dlou': 1,
#  'adinoopt': 1,
#  'abeeln': 1,
#  'ceersstw': 1,
#  'eefhor': 1,
#  'eeilt': 1,
#  'chikory': 1,
#  'deeefrrr': 1,
#  'aafkmnu': 1,
#  'ellms': 1,
#  'abehlrt': 1,
#  'emo': 1,
#  'aceeghnnop': 1,
#  'aaalntt': 1,
#  'eimprss': 1,
#  'abeijmnn': 1,
#  'aeilrs': 2,
#  'ehloopt': 1,
#  'acegnrsttu': 1,
#  'aacccruy': 1,
#  'eellpt': 1,
#  'aegimr': 1,
#  'ggghinu': 1,
#  'aceiillnstt': 1,
#  'aaaclp': 1,
#  'abddelnrtu': 1,
#  'aabbeeirtv': 1,
#  'huy': 1,
#  'aeehilppsy': 1,
#  'aiv': 1,
#  'ajnsu': 1,
#  'aisv': 3,
#  'cceeilopst': 1,
#  'aclnoot': 1,
#  'aaglwy': 1,
#  'ampst': 1,
#  'acenoruvv': 1,
#  'adhnostu': 1,
#  'deq': 1,
#  'ioorstu': 1,
#  'eeimnnstt': 1,
#  'afgisy': 1,
#  'aefilmnr': 1,
#  'ltt': 1,
#  'aablov': 1,
#  'iinnorstu': 1,
#  'eirstwz': 1,
#  'begkmos': 1,
#  'aaceinnntu': 1,
#  'aaaccdelv': 1,
#  'acdeeinntu': 1,
#  'acdhopry': 1,
#  'ikqru': 1,
#  'ceiiklqrsuv': 1,
#  'aacenr': 1,
#  'aacdlor': 1,
#  'cchikopst': 1,
#  'cghlnooory': 1,
#  'aeelst': 1,
#  'aimor': 2,
#  'cdiijru': 1,
#  'adeeeiimnnrtt': 1,
#  'alpu': 1,
#  'ceeimno': 1,
#  'aeimnnorstu': 1,
#  'el': 1,
#  'aaelppt': 1,
#  'eoruv': 1,
#  'aeeefnrrst': 1,
#  'gnsu': 2,
#  'eelmr': 2,
#  'defiioprsu': 1,
#  'efst': 1,
#  'abillsy': 1,
#  'fhinrsu': 1,
#  'kopr': 1,
#  'aehnt': 2,
#  'aefilnrt': 1,
#  'accefllotu': 1,
#  'accdinortt': 1,
#  'himsty': 1,
#  'acenoptw': 1,
#  'cgimnnoo': 2,
#  'aboss': 1,
#  'dinw': 1,
#  'filrt': 1,
#  'acdijortuy': 1,
#  'alnoopt': 1,
#  'amr': 3,
#  'epw': 1,
#  'aachnr': 1,
#  'affguw': 1,
#  'aiorrtt': 1,
#  'cdeir': 1,
#  'adej': 2,
#  'abeelly': 1,
#  'affhirs': 1,
#  'achnst': 2,
#  'mopr': 2,
#  'bhnopsttuu': 1,
#  'ceiikns': 1,
#  'diillnosww': 1,
#  'oopsw': 1,
#  'fillr': 1,
#  'cceeilrst': 1,
#  'adesty': 1,
#  'emw': 1,
#  'eknnoy': 1,
#  'aaceglotu': 2,
#  'acior': 1,
#  'eesttx': 1,
#  'ailsuv': 1,
#  'efhrs': 1,
#  'beehkloossv': 1,
#  'eitx': 1,
#  'ehiorsy': 1,
#  'aceefhitw': 1,
#  'cdilu': 1,
#  'ddemnos': 2,
#  'aabdlnsst': 1,
#  'eiilorv': 1,
#  'bdiiilnosu': 1,
#  'adisu': 1,
#  'eirsst': 2,
#  'ahortu': 1,
#  'bcghilooopsyy': 1,
#  'aimty': 1,
#  'aaginrr': 1,
#  'afilmy': 1,
#  'aaeltuv': 1,
#  'eehnnorrsttw': 1,
#  'ceorsw': 1,
#  'acddeehlort': 1,
#  'behiklosv': 1,
#  'ittwy': 1,
#  'aoooprtz': 1,
#  'aoprst': 1,
#  'immopprtu': 1,
#  'osu': 1,
#  'achnos': 1,
#  'abgiillnu': 1,
#  'beehilmn': 1,
#  'giilnoorsu': 1,
#  'aabbilrt': 1,
#  'eelop': 1,
#  'ailv': 2,
#  'eeiipqrstu': 1,
#  'deorr': 1,
#  'aegv': 2,
#  'achimmoss': 1,
#  'acceklr': 1,
#  'aefflw': 1,
#  'bceeefinnt': 1,
#  'adhilooprs': 1,
#  'abeefglortt': 1,
#  'aciimnnoosstu': 1,
#  'adelmops': 1,
#  'bmoux': 1,
#  'adem': 3,
#  'eiilnoorrstu': 1,
#  'adelmn': 1,
#  'dgi': 1,
#  'ddiors': 1,
#  'aabeln': 1,
#  'cehtv': 1,
#  'adeefn': 1,
#  'ahiinorst': 1,
#  'aabeiillmss': 1,
#  'ddmu': 1,
#  'aeeinpsvx': 1,
#  'hi': 1,
#  'aeeimss': 1,
#  'beeeiilrrrsv': 1,
#  'acrtt': 1,
#  'aaorru': 1,
#  'cdiinnooopstt': 1,
#  'bdotu': 1,
#  'eegnr': 2,
#  'abciinnrt': 1,
#  'cikns': 1,
#  'acefiostu': 1,
#  'eegnorssv': 1,
#  'deeefmnr': 1,
#  'eghhilostu': 1,
#  'ceeilrrstuu': 1,
#  'abegoz': 1,
#  'adeehiln': 1,
#  'adguy': 1,
#  'abbdel': 1,
#  'achirty': 1,
#  'abeipstt': 1,
#  'eeilnv': 1,
#  'achmnor': 1,
#  'anorsttt': 1,
#  'aaegirttv': 1,
#  'acdeiilnnot': 1,
#  'cdeopru': 1,
#  'aefgilr': 1,
#  'agiikl': 1,
#  'aachimnor': 1,
#  'ikst': 1,
#  'lnoy': 2,
#  'cenortvy': 1,
#  'eopssss': 1,
#  'afflopy': 1,
#  'hmsuy': 1,
#  'aceiilnott': 1,
#  'accilorrtuy': 1,
#  'aadir': 1,
#  'aalpy': 1,
#  'eelnxy': 1,
#  'deiinoprss': 1,
#  'aabcehru': 1,
#  'ilmnot': 1,
#  'bcehrstu': 1,
#  'acegy': 1,
#  'aegimqru': 1,
#  'aceefhrs': 1,
#  'aefkmorrw': 1,
#  'eeelst': 1,
#  'aeelmnsu': 1,
#  'ceehlloorst': 1,
#  'acepr': 1,
#  'klnorsty': 1,
#  'ddeein': 1,
#  'ago': 3,
#  'enoxx': 1,
#  'ccefnot': 1,
#  'aelruv': 1,
#  'elopz': 1,
#  'aalrt': 1,
#  'chill': 1,
#  'abdefilmor': 1,
#  'acginoostu': 1,
#  'abgimt': 1,
#  'ehnorstu': 1,
#  'adeelny': 1,
#  'eeklly': 1,
#  'eeilnpstt': 1,
#  'dgilmnsu': 1,
#  'abeeffiln': 1,
#  'abnort': 1,
#  'efoorrsw': 1,
#  'aabegost': 1,
#  'eiimnoprss': 2,
#  'aabelt': 1,
#  'eeginorrss': 1,
#  'abno': 1,
#  'einst': 2,
#  'abdemru': 1,
#  'aceilnp': 2,
#  'aalmnttu': 1,
#  'cijnnoot': 1,
#  'iklo': 1,
#  'acipty': 1,
#  'abeilllrsty': 1,
#  'aanrs': 1,
#  "'dit": 1,
#  'aeghilry': 1,
#  'abbirsuu': 1,
#  'begilnnu': 1,
#  'ceelnort': 1,
#  'cceilrt': 1,
#  'ilms': 1,
#  'aaaeglt': 1,
#  'iinooppsstu': 1,
#  'cchrtu': 1,
#  'hoost': 2,
#  'anrw': 1,
#  'below': 3,
#  'ciprs': 1,
#  'eeegmnrss': 1,
#  'acdimmoruy': 1,
#  'cdeeinopt': 1,
#  'abccdeehkorr': 1,
#  'aceno': 2,
#  'ceeehilooprrsst': 1,
#  'aeginu': 1,
#  'adehmmmo': 1,
#  'ipty': 1,
#  'abeiilmt': 1,
#  'aeeeglrv': 1,
#  'acccegiinnor': 1,
#  'eflmosu': 1,
#  'aehjnnos': 2,
#  'ceinooprstu': 1,
#  'eiijm': 1,
#  'egor': 2,
#  'aeinoopprt': 1,
#  'eeinsttx': 1,
#  'adfinnootu': 1,
#  'adiilnopsttuu': 1,
#  'adnoty': 1,
#  'acilmmnooty': 1,
#  'iimrttu': 1,
#  'deiimnrtw': 1,
#  'gggilno': 1,
#  'celruw': 1,
#  'aaaegnnrrstt': 1,
#  'acemnu': 1,
#  'aailmos': 1,
#  'abden': 1,
#  'abdeeelmn': 1,
#  'cegorsu': 1,
#  'eimnrv': 2,
#  'acegillr': 1,
#  'ceeimnstu': 1,
#  'bfilmru': 1,
#  'aaadelmnrs': 1,
#  'aggnnopyy': 1,
#  'adinpsttu': 1,
#  'aeggiopr': 1,
#  'aacfltu': 1,
#  'ceiklorstw': 1,
#  'cdeeiiinsv': 1,
#  'eipty': 1,
#  'aadkr': 1,
#  'eehlt': 2,
#  'aadeiloprtz': 1,
#  'ejnos': 1,
#  'aehlssty': 1,
#  'aelstv': 1,
#  'aelrst': 1,
#  'aeeilnnpst': 1,
#  'deekr': 1,
#  'aahrsu': 1,
#  'adeghorsuu': 1,
#  'eenoprxy': 1,
#  'cdlo': 2,
#  'eimor': 1,
#  'eeprtu': 1,
#  'egimost': 1,
#  'alrtw': 1,
#  'eemnyz': 1,
#  'adehirw': 1,
#  'abhor': 1,
#  'aberuu': 1,
#  'addiv': 1,
#  'aekp': 1,
#  'defghilot': 1,
#  'cijnnoo': 1,
#  'adelln': 1,
#  'aabms': 1,
#  'aabcloruvy': 1,
#  'abcelrstu': 1,
#  'deeflmmors': 1,
#  'aaagorst': 1,
#  'cehilnop': 2,
#  'aclsu': 2,
#  'adefgilru': 1,
#  'egillnorstty': 1,
#  'aadegiprs': 1,
#  'cdeeeimnort': 1,
#  'bciimosty': 1,
#  'hlost': 2,
#  'agruuuy': 1,
#  'dstuy': 2,
#  'ahoosttw': 1,
#  'abefilll': 1,
#  'efls': 1,
#  'clmoooorty': 1,
#  'aelpt': 4,
#  'cnr': 2,
#  'aacehp': 1,
#  'aeflrzz': 1,
#  'aceeelortt': 1,
#  'aky': 2,
#  'acefiirtv': 1,
#  'bcdeeemr': 1,
#  'ehltu': 1,
#  'acdeeffhrt': 1,
#  'ccciiimnorsu': 1,
#  'eeestv': 1,
#  'aghmnoopr': 1,
#  'ghiorsu': 1,
#  'abeehv': 1,
#  'aelntt': 2,
#  'emrt': 1,
#  'aacrttt': 1,
#  'abekr': 2,
#  'eghhi': 1,
#  'cefflsu': 1,
#  'eeiiqstux': 1,
#  'ackls': 1,
#  ...}

# %%
# Counter
from collections import Counter

# %%
anagram_lst_2 = [get_signiture(word) for word in english_words]

# %%
anagram_counter = Counter(anagram_lst_2)

# %%
anagram_counter.most_common(10)
# Out:
# [('aeln', 5),
#  ('aegln', 5),
#  ('acert', 5),
#  ('abel', 5),
#  ('eilv', 5),
#  ('aeglr', 5),
#  ('elmno', 4),
#  ('abder', 4),
#  ('aelpt', 4),
#  ('ailm', 4)]

# %%
anagram_lst['eilv']
# Out:
# ['live', 'vile', 'levi', 'evil', 'veil']

# %% [markdown]
# *_:)_*
